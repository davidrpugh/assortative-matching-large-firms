# %%
# %load_ext autoreload

# %%
autoreload 2

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy as sym

import inputs
import models
import shooting

from __future__ import division

# %%
# define some workers skill
x, a, b = sym.var('x, a, b')
skill_cdf = (x - a) / (b - a)
skill_params = {'a': 1.0, 'b': 2.0}
skill_bounds = [skill_params['a'], skill_params['b']]

workers = inputs.Input(var=x,
                       cdf=skill_cdf,
                       params=skill_params,
                       bounds=skill_bounds,
                       )

# define some firms
y = sym.var('y')
productivity_cdf = (y - a) / (b - a)
productivity_params = skill_params
productivity_bounds = skill_bounds

firms = inputs.Input(var=y,
                     cdf=productivity_cdf,
                     params=productivity_params,
                     bounds=productivity_bounds,
                     )

# %%
# Developped country

R, l, r, rho, gamma, eta, L, A, kapa = sym.var('R, l, r, rho, gamma, eta, L, A, kapa')

# First set k to the optimum (look at Capital notebook)
k_star = (2*6**(-0.5)*(A*eta**2*kapa*x**0.5/R)**0.5*sym.cos(0.333333333333333*sym.acos(3*6**0.5*x**(-0.5)*(l*x*y/r)**0.25*(R*x**(-0.5)/(A*eta**2*kapa))**0.5*(-eta + 1)/(2*eta))))**(4)

F = A*kapa*(eta*(k_star*x)**rho + (1- eta)*(y*(l/r))**rho)**(gamma/rho)

F_params = {'R':0.13099, 'rho':0.25, 'gamma':0.5, 'eta':0.89, 'L':4.2, 'A': 1.0, 'kapa':1.0}

# %% [markdown]
# Checking capital...

# %%
# Try out positive
model = models.Model('positive',
                     workers=workers,
                     firms=firms,
                     production=F,
                     params=F_params)

solver = shooting.ShootingSolver(model=model)

# %%
solver.solve(10, tol=1e-6, number_knots=100, atol=1e-15, rtol=1e-12)
# Out:
# Success! All workers and firms are matched

# %%
solver.solution
# Out:
#           $\mu(x)$  $\theta(x)$    $w(x)$  $\pi(x)$
# x
# 1.000000  1.000000     3.000178  0.061186  2.914672
# 1.010101  1.003401     2.939583  0.062447  2.939121
# 1.020202  1.006872     2.880465  0.063728  2.963565
# 1.030303  1.010415     2.822776  0.065031  2.988006
# 1.040404  1.014030     2.766469  0.066354  3.012442
# 1.050505  1.017718     2.711500  0.067700  3.036875
# 1.060606  1.021481     2.657826  0.069067  3.061303
# 1.070707  1.025319     2.605406  0.070456  3.085728
# 1.080808  1.029235     2.554202  0.071869  3.110149
# 1.090909  1.033229     2.504174  0.073305  3.134567
# 1.101010  1.037303     2.455287  0.074764  3.158981
# 1.111111  1.041457     2.407506  0.076248  3.183391
# 1.121212  1.045694     2.360799  0.077757  3.207798
# 1.131313  1.050015     2.315132  0.079290  3.232202
# 1.141414  1.054421     2.270475  0.080850  3.256603
# 1.151515  1.058913     2.226799  0.082436  3.281000
# 1.161616  1.063494     2.184074  0.084048  3.305395
# 1.171717  1.068163     2.142274  0.085688  3.329786
# 1.181818  1.072924     2.101372  0.087356  3.354175
# 1.191919  1.077778     2.061342  0.089052  3.378560
# 1.202020  1.082725     2.022161  0.090778  3.402943
# 1.212121  1.087769     1.983804  0.092533  3.427323
# 1.222222  1.092909     1.946248  0.094319  3.451700
# 1.232323  1.098149     1.909473  0.096135  3.476075
# 1.242424  1.103490     1.873456  0.097983  3.500447
# 1.252525  1.108933     1.838178  0.099864  3.524817
# 1.262626  1.114481     1.803619  0.101777  3.549184
# 1.272727  1.120134     1.769759  0.103725  3.573549
# 1.282828  1.125896     1.736581  0.105706  3.597911
# 1.292929  1.131768     1.704067  0.107723  3.622271
# ...            ...          ...       ...       ...
# 1.707071  1.498031     0.786404  0.233426  4.619494
# 1.717172  1.511000     0.771421  0.237960  4.643787
# 1.727273  1.524221     0.756697  0.242591  4.668080
# 1.737374  1.537700     0.742227  0.247320  4.692371
# 1.747475  1.551441     0.728006  0.252151  4.716661
# 1.757576  1.565451     0.714030  0.257087  4.740950
# 1.767677  1.579736     0.700294  0.262129  4.765239
# 1.777778  1.594301     0.686795  0.267281  4.789526
# 1.787879  1.609153     0.673528  0.272546  4.813812
# 1.797980  1.624298     0.660489  0.277926  4.838098
# 1.808081  1.639742     0.647675  0.283425  4.862382
# 1.818182  1.655492     0.635080  0.289046  4.886666
# 1.828283  1.671554     0.622702  0.294792  4.910948
# 1.838384  1.687937     0.610537  0.300666  4.935230
# 1.848485  1.704646     0.598581  0.306671  4.959511
# 1.858586  1.721689     0.586830  0.312812  4.983790
# 1.868687  1.739074     0.575281  0.319092  5.008069
# 1.878788  1.756808     0.563932  0.325514  5.032348
# 1.888889  1.774900     0.552777  0.332082  5.056625
# 1.898990  1.793357     0.541815  0.338801  5.080901
# 1.909091  1.812189     0.531042  0.345674  5.105177
# 1.919192  1.831403     0.520454  0.352706  5.129452
# 1.929293  1.851008     0.510050  0.359901  5.153726
# 1.939394  1.871014     0.499825  0.367264  5.177999
# 1.949495  1.891429     0.489777  0.374798  5.202272
# 1.959596  1.912264     0.479904  0.382509  5.226544
# 1.969697  1.933529     0.470201  0.390402  5.250815
# 1.979798  1.955232     0.460667  0.398482  5.275085
# 1.989899  1.977386     0.451300  0.406753  5.299355
# 2.000000  2.000000     0.442095  0.415222  5.323623
#
# [100 rows x 4 columns]

# %%
sol1 = solver.solution

# %%
sol1.plot()
plt.show()

# %%
xs = []
thetas = []
ys = []
for i in range(100):
    xs.append(sol1.index[i])
    ys.append(sol1.iloc[i,0])
    thetas.append(sol1.iloc[i,1])
eval_k = sym.lambdify((x,y,l,r,A,kapa,eta,R), k_star)
ks = []
for a in range(len(xs)):
    ks.append(eval_k(xs[a],ys[a],thetas[a],1,1,1,0.89,0.13099))

# %%
plt.plot(xs, ks, label="Capital")
plt.legend(loc=2)
plt.xlim(1,2)
plt.title("Rich country")
plt.show()

# %%
solver.residuals.plot(logy=True, alpha=0.5)
plt.show()

# %%
# Not-so-Developped country

F_params2 = {'R':0.83684, 'rho':0.25, 'gamma':0.5, 'eta':0.89, 'L':5.46, 'A': 0.5105, 'kapa':1.0}

model2 = models.Model('positive',
                     workers=workers,
                     firms=firms,
                     production=F,
                     params=F_params2)

solver = shooting.ShootingSolver(model=model2)

# %%
solver.solve(1.0, tol=1e-6, number_knots=100, atol=1e-15, rtol=1e-12)
# Out:
# Success! All workers and firms are matched

# %%
solver.solution
# Out:
#           $\mu(x)$  $\theta(x)$    $w(x)$  $\pi(x)$
# x
# 1.000000  1.000000     2.517564  0.012033  0.174572
# 1.010101  1.004046     2.475778  0.012236  0.175642
# 1.020202  1.008160     2.434783  0.012442  0.176712
# 1.030303  1.012343     2.394558  0.012651  0.177781
# 1.040404  1.016597     2.355084  0.012863  0.178848
# 1.050505  1.020922     2.316341  0.013078  0.179915
# 1.060606  1.025319     2.278312  0.013297  0.180980
# 1.070707  1.029789     2.240978  0.013518  0.182045
# 1.080808  1.034334     2.204322  0.013743  0.183109
# 1.090909  1.038954     2.168328  0.013971  0.184171
# 1.101010  1.043651     2.132980  0.014203  0.185233
# 1.111111  1.048426     2.098261  0.014438  0.186294
# 1.121212  1.053280     2.064158  0.014676  0.187354
# 1.131313  1.058213     2.030655  0.014918  0.188413
# 1.141414  1.063228     1.997739  0.015164  0.189472
# 1.151515  1.068326     1.965396  0.015414  0.190529
# 1.161616  1.073508     1.933613  0.015667  0.191586
# 1.171717  1.078774     1.902376  0.015924  0.192642
# 1.181818  1.084128     1.871675  0.016186  0.193697
# 1.191919  1.089568     1.841497  0.016451  0.194751
# 1.202020  1.095098     1.811829  0.016720  0.195805
# 1.212121  1.100719     1.782662  0.016994  0.196858
# 1.222222  1.106431     1.753984  0.017272  0.197910
# 1.232323  1.112237     1.725785  0.017554  0.198962
# 1.242424  1.118138     1.698054  0.017840  0.200012
# 1.252525  1.124135     1.670781  0.018132  0.201062
# 1.262626  1.130230     1.643957  0.018428  0.202112
# 1.272727  1.136424     1.617573  0.018728  0.203160
# 1.282828  1.142719     1.591619  0.019034  0.204208
# 1.292929  1.149117     1.566086  0.019344  0.205256
# ...            ...          ...       ...       ...
# 1.707071  1.525247     0.799952  0.037870  0.247748
# 1.717172  1.537981     0.786590  0.038513  0.248775
# 1.727273  1.550931     0.773426  0.039169  0.249803
# 1.737374  1.564102     0.760457  0.039837  0.250829
# 1.747475  1.577498     0.747680  0.040517  0.251856
# 1.757576  1.591123     0.735093  0.041211  0.252882
# 1.767677  1.604982     0.722693  0.041918  0.253908
# 1.777778  1.619078     0.710476  0.042639  0.254933
# 1.787879  1.633418     0.698441  0.043374  0.255959
# 1.797980  1.648005     0.686584  0.044123  0.256984
# 1.808081  1.662843     0.674904  0.044887  0.258008
# 1.818182  1.677939     0.663397  0.045665  0.259032
# 1.828283  1.693297     0.652061  0.046459  0.260056
# 1.838384  1.708923     0.640893  0.047269  0.261080
# 1.848485  1.724821     0.629892  0.048094  0.262103
# 1.858586  1.740997     0.619054  0.048936  0.263126
# 1.868687  1.757456     0.608378  0.049795  0.264149
# 1.878788  1.774205     0.597862  0.050671  0.265172
# 1.888889  1.791249     0.587502  0.051564  0.266194
# 1.898990  1.808593     0.577297  0.052476  0.267216
# 1.909091  1.826245     0.567245  0.053406  0.268238
# 1.919192  1.844210     0.557344  0.054354  0.269259
# 1.929293  1.862494     0.547590  0.055323  0.270280
# 1.939394  1.881105     0.537984  0.056310  0.271301
# 1.949495  1.900048     0.528522  0.057319  0.272322
# 1.959596  1.919331     0.519202  0.058347  0.273342
# 1.969697  1.938960     0.510023  0.059398  0.274362
# 1.979798  1.958943     0.500982  0.060469  0.275382
# 1.989899  1.979287     0.492079  0.061564  0.276402
# 2.000000  2.000000     0.483310  0.062680  0.277421
#
# [100 rows x 4 columns]

# %%
solver.residuals.plot(logy=True, alpha=0.5)
plt.show()

# %%
sol2 = solver.solution

# %%
sol2.plot()
plt.show()

# %%
xs2 = []
thetas2 = []
ys2 = []
for i in range(100):
    xs2.append(sol2.index[i])
    ys2.append(sol2.iloc[i,0])
    thetas2.append(sol2.iloc[i,1])

# %%
ks2 = []
for a in range(len(xs)):
    ks2.append(eval_k(xs2[a],ys2[a],thetas2[a],1,0.5105,1,0.89,0.83684))

# %%
plt.plot(xs2, ks2, label="Capital")
plt.legend(loc=1)
plt.xlim(1,2)
plt.title("Poor Country")
plt.show()

# %%
#plt.plot(xs, ks, label="Capital - Rich")
sol1.plot()
sol2.plot()
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlim(1,2)
plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.plot(xs, ys, label="Land quality- Rich")
ax1.plot(xs, thetas, label="Labour- Rich")
ax1.plot(xs2, ks2, label="Capital - Poor")
ax1.plot(xs2, ys2, label="Land quality- Poor")
ax1.plot(xs2, thetas2, label="Labour- Poor")
ax1.plot(xs, ks, label="Capital - Rich")

ax1.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)


plt.xlim(1,2)
plt.title("Both Countries")
plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
plt.plot(xs, ks, label="Rich")

ax2 = ax1.twinx()
plt.plot(xs2, ks2, label="Poor", c='g')
ax2.set_ylabel('Poor')

ax1.legend(bbox_to_anchor=(1.1, 1), loc=2, borderaxespad=0.)
ax2.legend(bbox_to_anchor=(1.065, 0.95), loc=2, borderaxespad=1)
plt.xlim(1,2)
plt.title("Capital")
plt.show()
