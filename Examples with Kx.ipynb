# %%
# %load_ext autoreload

# %%
autoreload 2

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy as sym

import inputs
import models
import shooting

from __future__ import division

# %% [markdown]
# # Calibrating the Adamopoulos and Restuccia(2014) paper with $x$, classical version
#
# This notebook solves for a model with two-sided heterogeneity and firm size when capital also enters the production function.
#
# In particular, the production function takes the form:
#
# $$F(x,y,l,r,k) = A\kappa( (kx)^{\rho} \eta + (1-\eta) (yl/r)^{\rho})^{\gamma/\rho}$$
#
# The solution for optimal capital ($k(x,y,l,r)$) can be found in the Capital.ipynb notebook.
#
# First, workers and firms are created - we assume worker skill is very homogeneous, and that firm skill follows a lognormal distribution.
#
# Then the model is solved for Rich ($A=1,R=0.13099$) and Poor ($A=0.5105,R=0.83684$) countries and then comapres the solution.

# %%
# define some workers skill
x, a, b = sym.var('x, a, b')
skill_cdf = (x - a) / (b - a)
skill_params = {'a': 0.99, 'b': 1.01}
skill_bounds = [skill_params['a'], skill_params['b']]

workers = inputs.Input(var=x,
                       cdf=skill_cdf,
                       params=skill_params,
                       bounds=skill_bounds,
                       )

# define some firms lognorm.pdf(x, s) = 1 / (s*x*sqrt(2*pi)) * exp(-1/2*(log(x)/s)**2)
y, mu2, sigma2 = sym.var('y, mu2, sigma2')
productivity_cdf = 0.5 + 0.5 * sym.erf((sym.log(y) - mu2) / (sym.sqrt(2) * sigma2))
productivity_params = {'mu2': -1.83, 'sigma2': 4.66}
productivity_bounds = [1e-3, 10.0]

firms = inputs.Input(var=y,
                     cdf=productivity_cdf,
                     params=productivity_params,
                     bounds=productivity_bounds,
                     )

# %% [markdown]
# ## 1.Solving for the Rich Country

# %%
# Developped country

R, l, r, rho, gamma, eta, L, A, kapa = sym.var('R, l, r, rho, gamma, eta, L, A, kapa')

# First set k to the optimum (look at Capital notebook)
k_star = (2*6**(-0.5)*(A*eta**2*kapa*x**0.5/R)**0.5*sym.cos(0.333333333333333*sym.acos(3*6**0.5*x**(-0.5)*(l*x*y/r)**0.25*(R*x**(-0.5)/(A*eta**2*kapa))**0.5*(-eta + 1)/(2*eta))))**(4)

F = A*kapa*(eta*(k_star*x)**rho + (1- eta)*(y*(l/r))**rho)**(gamma/rho)

F_params = {'R':0.13099, 'rho':0.25, 'gamma':0.5, 'eta':0.89, 'L':4.2, 'A': 1.0, 'kapa':1.0}

# %%
# Try out positive
model = models.Model('positive',
                     workers=workers,
                     firms=firms,
                     production=F,
                     params=F_params)

solver = shooting.ShootingSolver(model=model)

# %%
solver.solve(0.01, tol=1e-6, number_knots=1000, atol=1e-15, rtol=1e-12, integrator='lsoda')
# Out:
# Success! All workers and firms are matched

# %%
solver.solution
# Out:
#            $\mu(x)$  $\theta(x)$     $w(x)$  $\pi(x)$
# x
# 0.990000   0.001000    17.663588   0.002690  2.511114
# 0.990020   0.001001    17.641741   0.002693  2.511162
# 0.990040   0.001002    17.619901   0.002697  2.511210
# 0.990060   0.001004    17.598068   0.002700  2.511258
# 0.990080   0.001005    17.576242   0.002703  2.511306
# 0.990100   0.001006    17.554423   0.002707  2.511354
# 0.990120   0.001007    17.532610   0.002710  2.511402
# 0.990140   0.001008    17.510804   0.002713  2.511450
# %%
# Saving results into sol1
sol1 = solver.solution

xs = sol1.index.values
ys = sol1['$\\mu(x)$'].values
thetas = sol1['$\\theta(x)$'].values
ws = sol1['$w(x)$'].values
# For capital lambdify k_star
eval_k = sym.lambdify((x,y,l,r,A,kapa,eta,R), k_star)
ks = []
for a in range(len(xs)):
    ks.append(eval_k(xs[a],ys[a],thetas[a],1,1,1,0.89,0.13099))

# %%
# Plotting the solution
plt.plot(ys, ks, label="Capital")
plt.plot(ys, xs, label="Land quality")
plt.plot(ys, thetas, label="Land")
plt.legend(loc='best')
plt.xlim(0.0,0.2)
plt.ylim(0.0,10.0)
plt.title("Rich country")
plt.show()

# %%
#Plotting the Residuals
solver.residuals.plot(logy=True, alpha=0.5)
plt.title("Residuals (Relative)")
plt.show()

# %% [markdown]
# ## 2.Solving for the Poor Country

# %%
# Not-so-Developped country

F_params2 = {'R':0.83684, 'rho':0.25, 'gamma':0.5, 'eta':0.89, 'L':5.46, 'A': 0.5105, 'kapa':1.0}

model2 = models.Model('positive',
                     workers=workers,
                     firms=firms,
                     production=F,
                     params=F_params2)

solver = shooting.ShootingSolver(model=model2)

# %%
solver.solve(0.01, tol=1e-6, number_knots=1000, atol=1e-15, rtol=1e-12, integrator='lsoda')
# Out:
# Success! All workers and firms are matched

# %%
solver.solution
# Out:
#            $\mu(x)$  $\theta(x)$    $w(x)$  $\pi(x)$
# x
# 0.990000   0.001000    17.626983  0.000413  0.117371
# 0.990020   0.001001    17.605212  0.000414  0.117373
# 0.990040   0.001002    17.583447  0.000414  0.117375
# 0.990060   0.001004    17.561688  0.000415  0.117377
# 0.990080   0.001005    17.539937  0.000415  0.117379
# 0.990100   0.001006    17.518192  0.000416  0.117381
# 0.990120   0.001007    17.496454  0.000417  0.117383
# 0.990140   0.001008    17.474723  0.000417  0.117385
# 0.990160   0.001010    17.452998  0.000418  0.117387
# 0.990180   0.001011    17.431280  0.000418  0.117389
# 0.990200   0.001012    17.409569  0.000419  0.117391
# 0.990220   0.001013    17.387864  0.000419  0.117393
# 0.990240   0.001015    17.366167  0.000420  0.117395
# 0.990260   0.001016    17.344476  0.000420  0.117397
# 0.990280   0.001017    17.322791  0.000421  0.117399
# 0.990300   0.001018    17.301114  0.000421  0.117401
# 0.990320   0.001020    17.279443  0.000422  0.117403
# 0.990340   0.001021    17.257779  0.000422  0.117405
# 0.990360   0.001022    17.236122  0.000423  0.117407
# 0.990380   0.001023    17.214471  0.000423  0.117409
# 0.990400   0.001025    17.192827  0.000424  0.117411
# 0.990420   0.001026    17.171190  0.000424  0.117413
# 0.990440   0.001027    17.149560  0.000425  0.117415
# 0.990460   0.001028    17.127936  0.000425  0.117417
# 0.990480   0.001030    17.106319  0.000426  0.117419
# 0.990501   0.001031    17.084709  0.000427  0.117421
# 0.990521   0.001032    17.063106  0.000427  0.117423
# 0.990541   0.001033    17.041510  0.000428  0.117425
# 0.990561   0.001035    17.019920  0.000428  0.117427
# 0.990581   0.001036    16.998337  0.000429  0.117429
# ...             ...          ...       ...       ...
# 1.009419   0.049026     0.347882  0.020949  0.119288
# 1.009439   0.050787     0.335805  0.021702  0.119290
# 1.009459   0.052677     0.323751  0.022510  0.119292
# 1.009479   0.054708     0.311720  0.023379  0.119294
# 1.009499   0.056898     0.299713  0.024316  0.119296
# 1.009520   0.059265     0.287729  0.025328  0.119298
# 1.009540   0.061834     0.275769  0.026427  0.119300
# 1.009560   0.064629     0.263831  0.027623  0.119302
# 1.009580   0.067684     0.251916  0.028929  0.119304
# 1.009600   0.071035     0.240024  0.030363  0.119306
# 1.009620   0.074728     0.228155  0.031942  0.119308
# 1.009640   0.078818     0.216307  0.033692  0.119310
# 1.009660   0.083374     0.204481  0.035640  0.119312
# 1.009680   0.088479     0.192676  0.037824  0.119314
# 1.009700   0.094240     0.180892  0.040288  0.119316
# 1.009720   0.100793     0.169126  0.043091  0.119318
# 1.009740   0.108313     0.157378  0.046307  0.119320
# 1.009760   0.117033     0.145646  0.050037  0.119321
# 1.009780   0.127269     0.133929  0.054415  0.119323
# 1.009800   0.139454     0.122222  0.059627  0.119325
# 1.009820   0.154210     0.110523  0.065939  0.119327
# 1.009840   0.172455     0.098827  0.073743  0.119329
# 1.009860   0.195609     0.087126  0.083646  0.119331
# 1.009880   0.225990     0.075411  0.096641  0.119333
# 1.009900   0.267669     0.063666  0.114468  0.119335
# 1.009920   0.328531     0.051870  0.140500  0.119337
# 1.009940   0.426198     0.039982  0.182275  0.119339
# 1.009960   0.610158     0.027927  0.260959  0.119341
# 1.009980   1.098216     0.015515  0.469713  0.119343
# 1.010000  10.000000     0.001704  4.277200  0.119345
#
# [1000 rows x 4 columns]

# %%
solver.residuals.plot(logy=True, alpha=0.5)
plt.show()

# %%
# Saving results into sol2
sol2 = solver.solution

xs2 = sol2.index.values
ys2 = sol2['$\\mu(x)$'].values
thetas2 = sol2['$\\theta(x)$'].values
ws2 = sol2['$w(x)$'].values
ks2 = []
for a in range(len(xs)):
    ks2.append(eval_k(xs2[a],ys2[a],thetas2[a],1,0.5105,1,0.89,0.83684))

# %%
plt.plot(ys2, ks2, label="Capital")
plt.plot(ys2, xs2, label="Land quality")
plt.plot(ys2, thetas2, label="Land")
plt.legend(loc='best')
plt.xlim(0.0,0.2)
plt.ylim(0.0,10.0)
plt.title("Poor country")
plt.show()

# %% [markdown]
# ## 3. Comparing Solutions
#
#
# ### All graphs have in the horizontal axis *farmer skill* ($y$)

# %% [markdown]
# Solutions

# %%
plt.plot(ys, ks, label="Capital - Rich")
plt.plot(ys, thetas, label="Plot Size- Rich")
plt.plot(ys2, ks2, label="Capital - Poor")
plt.plot(ys2, thetas2, label="Plot Size- Poor")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlim(0.0,0.2)
plt.title("Both Countries")
plt.show()

# %% [markdown]
# Plot size ($\theta$)

# %%
#ax1.plot(xs, ys, label="Land quality- Rich")
plt.plot(ys, thetas, label="Labour- Rich")
#ax1.plot(xs2, ks2, label="Capital - Poor")
#ax1.plot(xs2, ys2, label="Land quality- Poor")
plt.plot(ys2, thetas2, label="Labour- Poor")
#ax1.plot(xs, ks, label="Capital - Rich")

#plt.ylim(0,17)
plt.xlim(0,1.1)
plt.title("Both Countries - $\\theta(y)$", size=14)
plt.show()

# %% [markdown]
# Capital

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
plt.plot(ys, ks, label="Rich")

ax2 = ax1.twinx()
plt.plot(ys2, ks2, label="Poor", c='g')
ax2.set_ylabel('Poor')

ax1.legend(bbox_to_anchor=(1.1, 1), loc=2, borderaxespad=0.)
ax2.legend(bbox_to_anchor=(1.065, 0.95), loc=2, borderaxespad=1)
plt.xlim(0,1.1)
plt.title("Both Countries - $k(y)$", size=14)
plt.show()

# %% [markdown]
# ## Extra bit: Distributions

# %%
from scipy.interpolate import InterpolatedUnivariateSpline

# It is necessay for interpolation to order theta in ascending order
sateht = thetas[::-1]
sy = ys[::-1]
y_spl = InterpolatedUnivariateSpline(thetas[::-1], ys[::-1], k=5)
plt.plot(thetas, y_spl(thetas))
plt.scatter(thetas,ys)
plt.xlim(0,2)
plt.ylim(0,1)
plt.title("$y (\\theta)$", size=16)
plt.show()

# %%
theta_range_R = np.arange(0.1, 20, 0.1)
plt.plot(theta_range_R, firms.evaluate_pdf(y_spl(theta_range_R)), c='r')
plt.xlim(0,20)
#plt.ylim(0,10)
plt.title("Distribution of $\\theta$ , Rich country", size=16)
plt.show()

# %%
sateht2 = thetas2[::-1]
sy2 = ys2[::-1]
y_spl_P = InterpolatedUnivariateSpline(thetas2[::-1], ys2[::-1], k=5)
plt.plot(thetas2, firms.evaluate_pdf(y_spl_P(thetas2)), c='g')
plt.plot(theta_range_R, firms.evaluate_pdf(y_spl_P(theta_range_R)), c='orange')
plt.xlim(0,20)
#plt.ylim(0,10)
plt.title("Distribution of $\\theta$ , Poor country", size=16)
plt.show()

# %%
plt.plot(theta_range_R, firms.evaluate_pdf(y_spl_P(theta_range_R)), c='orange', label="Poor")
plt.plot(theta_range_R, firms.evaluate_pdf(y_spl(theta_range_R)), c='r', label="Rich")

plt.legend(loc='best')
plt.xlim(0,20)
#plt.ylim(0,14)
plt.title("Distribution of $\\theta$ , Both countries", size=16)
plt.show()

# %%
k_range = np.arange(0, 20, 0.001)

y_k = InterpolatedUnivariateSpline(ks, ys, k=5)
y_k2 = InterpolatedUnivariateSpline(ks2, ys2, k=5)
plt.plot(k_range, firms.evaluate_pdf(y_k(k_range)), c='orange', label="Rich")
plt.xlim(8,11)
plt.ylim(0,80)
plt.title("Capital distribution - Rich Country")
plt.show()

# %%
plt.plot(k_range, firms.evaluate_pdf(y_k2(k_range)), c='r', label="Poor")
plt.title("Capital distribution - Poor Country")
plt.ylim(0,80)
plt.xlim(0,1)
plt.show()
