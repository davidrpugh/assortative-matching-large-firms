# %%
# %load_ext autoreload

# %%
autoreload 2

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy as sym

import inputs
import models
import shooting

# %% [markdown]
# # Example:
#
# ## Worker skill and firm productivity are $\sim U[a, b]$...

# %%
# define some workers skill
x, a, b = sym.var('x, a, b')
skill_cdf = (x - a) / (b - a)
skill_params = {'a': 1.0, 'b': 2.0}
skill_bounds = [skill_params['a'], skill_params['b']]

workers = inputs.Input(var=x,
                       cdf=skill_cdf,
                       params=skill_params,
                       bounds=skill_bounds,
                       )

# define some firms
y = sym.var('y')
productivity_cdf = (y - a) / (b - a)
productivity_params = skill_params
productivity_bounds = skill_bounds

firms = inputs.Input(var=y,
                     cdf=productivity_cdf,
                     params=productivity_params,
                     bounds=productivity_bounds,
                     )

# %% [markdown]
# ## ...and production function is multiplicatively separable.
# A particularly attractive case arises under multiplicative separability of the form
#
# $$F(x, y, l, r) = A(x, y)B(l, r)$$
#
# In this case the condition for positive assortative matching can be written as
#
# $$\frac{AA_{xy}}{A_xA_y}\frac{BB_{lr}}{B_lB_r} \ge 1$$
#
# If $B$ has constant elasticity of substitution form, then we obtain an even simpler condition
#
# $$\frac{AA_{xy}}{A_xA_y} \frac{1}{\sigma_{lr}}\ge 1$$
#
# where $\sigma_{lr}$ is the elasticity of substitution between $l$ and $r$.
#
# Finally, if $A$ also has constant elasticity of substitution form, then we obtain an even simpler condition
#
# $$\frac{1}{\sigma_{xy}\sigma_{lr}}\ge 1 \iff \sigma_{xy}\sigma_{lr} \le 1$$
#
# where $\sigma_{xy}$ is the elasticity of substitution between $x$ and $y$.

# %%
# define symbolic expression for CES between x and y
omega_A, sigma_A = sym.var('omega_A, sigma_A')
A = ((omega_A * x**((sigma_A - 1) / sigma_A) + 
     (1 - omega_A) * y**((sigma_A - 1) / sigma_A))**(sigma_A / (sigma_A - 1))) 

# define symbolic expression for Cobb-Douglas between l and r
l, r, omega_B, sigma_B = sym.var('l, r, omega_B, sigma_B')
B = l**omega_B * r**(1 - omega_B)

F = A * B

# %% [markdown]
# Create an instance of the `models.Model` class and an instance of the `solvers.ShootingSolver` class...

# %% [markdown]
# ### Positive assortative matching

# %%
F_params = {'omega_A':0.25, 'omega_B':0.75, 'sigma_A':0.95, 'sigma_B':1.0}

model = models.Model(assortativity='positive',
                     workers=workers,
                     firms=firms,
                     production=F,
                     params=F_params)

solver = shooting.ShootingSolver(model=model)

# %%
solver.solve(1e1, tol=1e-6, number_knots=100, atol=1e-15, rtol=1e-12)
# Out:
# Success! All workers and firms are matched

# %%
# examine the solution attribute
solver.solution
# Out:
#           $\mu(x)$  $\theta(x)$    $w(x)$  $\pi(x)$
# x
# 1.000000  1.000000     0.304740  1.009436  0.102539
# 1.010101  1.031666     0.333492  1.012825  0.112590
# 1.020202  1.060752     0.361288  1.016194  0.122380
# 1.030303  1.087712     0.388244  1.019543  0.131944
# 1.040404  1.112885     0.414452  1.022872  0.141310
# 1.050505  1.136532     0.439987  1.026181  0.150502
# 1.060606  1.158861     0.464912  1.029470  0.159538
# [1000 rows x 2 columns]

# %% [markdown]
# Probably more useful to look at some descriptive statistics for absolute values of the residuals...

# %%
np.abs(solver.residuals).describe()
# Out:
#        $\hat{\mu}(x)$  $\hat{\theta}(x)$
# count    1.000000e+03       1.000000e+03
# mean     1.051776e-06       1.673978e-07
# std      1.041509e-05       1.661167e-06
# min      1.221245e-15       4.884981e-15
# 25%      1.430134e-12       7.795431e-13
# 50%      9.794832e-12       4.533263e-12
# 75%      2.109104e-10       6.688444e-11
# max      2.520122e-04       4.011588e-05

# %% [markdown]
# Here are what the absolute residuals look like...

# %%
np.abs(solver.residuals).plot(logy=True, alpha=0.5)

# %%
solver.interpolated_solution[[0, 1]].describe()
# Out:
#           $\mu(x)$  $\theta(x)$
# count  1000.000000  1000.000000
# mean      1.635977     1.224939
# std       0.262612     0.453910
# min       1.000000     0.304740
# 25%       1.449479     0.860031
# 50%       1.685494     1.271062
# 75%       1.858880     1.618795
# max       2.000000     1.928118

# %%
np.abs(solver.residuals[[0, 1]]) / solver.interpolated_solution[[0, 1]]
# Out:
#           $\hat{\mu}(x)$  $\hat{\theta}(x)$  $\mu(x)$  $\theta(x)$
# x
# 1.000000             NaN                NaN       NaN          NaN
# 1.001001             NaN                NaN       NaN          NaN
# 1.002002             NaN                NaN       NaN          NaN
# 1.003003             NaN                NaN       NaN          NaN
# 1.004004             NaN                NaN       NaN          NaN
# 1.005005             NaN                NaN       NaN          NaN
# 1.006006             NaN                NaN       NaN          NaN
# 1.007007             NaN                NaN       NaN          NaN
# 1.008008             NaN                NaN       NaN          NaN
# 1.009009             NaN                NaN       NaN          NaN
# 1.010010             NaN                NaN       NaN          NaN
# 1.011011             NaN                NaN       NaN          NaN
# 1.012012             NaN                NaN       NaN          NaN
# 1.013013             NaN                NaN       NaN          NaN
# 1.014014             NaN                NaN       NaN          NaN
# 1.015015             NaN                NaN       NaN          NaN
# 1.016016             NaN                NaN       NaN          NaN
# 1.017017             NaN                NaN       NaN          NaN
# 1.018018             NaN                NaN       NaN          NaN
# 1.019019             NaN                NaN       NaN          NaN
# 1.020020             NaN                NaN       NaN          NaN
# 1.021021             NaN                NaN       NaN          NaN
# 1.022022             NaN                NaN       NaN          NaN
# 1.023023             NaN                NaN       NaN          NaN
# 1.024024             NaN                NaN       NaN          NaN
# 1.025025             NaN                NaN       NaN          NaN
# 1.026026             NaN                NaN       NaN          NaN
# 1.027027             NaN                NaN       NaN          NaN
# 1.028028             NaN                NaN       NaN          NaN
# 1.029029             NaN                NaN       NaN          NaN
# ...                  ...                ...       ...          ...
# 1.970971             NaN                NaN       NaN          NaN
# 1.971972             NaN                NaN       NaN          NaN
# 1.972973             NaN                NaN       NaN          NaN
# 1.973974             NaN                NaN       NaN          NaN
# 1.974975             NaN                NaN       NaN          NaN
# 1.975976             NaN                NaN       NaN          NaN
# 1.976977             NaN                NaN       NaN          NaN
# 1.977978             NaN                NaN       NaN          NaN
# 1.978979             NaN                NaN       NaN          NaN
# 1.979980             NaN                NaN       NaN          NaN
# 1.980981             NaN                NaN       NaN          NaN
# 1.981982             NaN                NaN       NaN          NaN
# 1.982983             NaN                NaN       NaN          NaN
# 1.983984             NaN                NaN       NaN          NaN
# 1.984985             NaN                NaN       NaN          NaN
# 1.985986             NaN                NaN       NaN          NaN
# 1.986987             NaN                NaN       NaN          NaN
# 1.987988             NaN                NaN       NaN          NaN
# 1.988989             NaN                NaN       NaN          NaN
# 1.989990             NaN                NaN       NaN          NaN
# 1.990991             NaN                NaN       NaN          NaN
# 1.991992             NaN                NaN       NaN          NaN
# 1.992993             NaN                NaN       NaN          NaN
# 1.993994             NaN                NaN       NaN          NaN
# 1.994995             NaN                NaN       NaN          NaN
# 1.995996             NaN                NaN       NaN          NaN
# 1.996997             NaN                NaN       NaN          NaN
# 1.997998             NaN                NaN       NaN          NaN
# 1.998999             NaN                NaN       NaN          NaN
# 2.000000             NaN                NaN       NaN          NaN
#
# [1000 rows x 4 columns]

# %%
(np.abs(solver.residuals) / solver.interpolated_solution[['firm productivity', 'firm size']]).plot(logy=True, alpha=0.5)

# %% [markdown]
# ### Negative assortative matching

# %%
# negative assortativity requires that sigma_A * sigma_B > 1
F_params = {'omega_A':0.25, 'omega_B':0.5, 'sigma_A':1.5, 'sigma_B':1.0}

# %%
model = models.Model(assortativity='negative',
                     workers=workers,
                     firms=firms,
                     production=F,
                     params=F_params)

solver = shooting.ShootingSolver(model=model)

# %%
solver.solve(2e0, tol=1e-6, number_knots=100, atol=1e-15, rtol=1e-12)
# Out:
# Success! All workers and firms are matched

# %%
solver.solution
# Out:
#           firm productivity  firm size      wage    profit
# x
# 1.000000           2.000000   1.829639  0.630705  1.153963
# 1.010101           1.994455   1.813970  0.633368  1.148910
# 1.020202           1.988863   1.798401  0.636024  1.143826
# 1.030303           1.983222   1.782931  0.638673  1.138710
# 1.040404           1.977532   1.767557  0.641317  1.133564
# 1.050505           1.971792   1.752276  0.643954  1.128386
# 1.060606           1.966003   1.737087  0.646586  1.123175
# 1.070707           1.960162   1.721986  0.649212  1.117933
# 1.080808           1.954271   1.706973  0.651832  1.112659
# 1.090909           1.948327   1.692044  0.654446  1.107352
# 1.101010           1.942331   1.677197  0.657056  1.102012
# 1.111111           1.936282   1.662431  0.659660  1.096639
# 1.121212           1.930179   1.647743  0.662259  1.091233
# 1.131313           1.924021   1.633132  0.664853  1.085793
# 1.141414           1.917808   1.618594  0.667443  1.080319
# 1.151515           1.911540   1.604130  0.670027  1.074810
# 1.161616           1.905214   1.589736  0.672607  1.069268
# 1.171717           1.898832   1.575410  0.675183  1.063690
# 1.181818           1.892391   1.561152  0.677754  1.058076
# 1.191919           1.885891   1.546958  0.680321  1.052428
# 1.202020           1.879331   1.532828  0.682883  1.046743
# 1.212121           1.872711   1.518759  0.685442  1.041022
# 1.222222           1.866029   1.504751  0.687997  1.035264
# 1.232323           1.859285   1.490800  0.690548  1.029469
# 1.242424           1.852478   1.476906  0.693095  1.023637
# 1.018018      -1.125966e-11  8.265766e-11
# 1.019019      -1.119416e-11  8.215117e-11
# 1.020020      -1.016365e-11  7.461920e-11
# 1.021021      -8.382850e-12  6.164158e-11
# 1.022022      -6.093348e-12  4.498180e-11
# 1.023023      -3.549383e-12  2.648659e-11
# 1.024024      -1.003198e-12  7.973844e-12
# 1.025025       1.311284e-12 -8.878231e-12
# 1.026026       3.193557e-12 -2.263723e-11
# 1.027027       4.492517e-12 -3.222178e-11
# 1.028028       5.120793e-12 -3.701173e-11
# 1.029029       5.072054e-12 -3.695266e-11
# ...                     ...           ...
# 1.970971      -6.247270e-08 -1.871536e-08
# 1.971972      -6.222474e-08 -1.859645e-08
# 1.972973      -5.396202e-08 -1.607058e-08
# 1.973974      -3.778150e-08 -1.117301e-08
# 1.974975      -1.468906e-08 -4.212095e-09
# 1.975976       1.355891e-08  4.279018e-09
# 1.976977       4.461770e-08  1.359188e-08
# 1.977978       7.572051e-08  2.289319e-08
# 1.978979       1.038487e-07  3.127639e-08
# 1.979980       1.259063e-07  3.781428e-08
# 1.980981       1.388989e-07  4.161288e-08
# 1.981982       1.401167e-07  4.186639e-08
# 1.982983       1.273226e-07  3.791333e-08
# 1.983984       9.894470e-08  2.929402e-08
# 1.984985       5.427369e-08  1.580916e-08
# 1.985986      -6.334793e-09 -2.420142e-09
# 1.986987      -8.125252e-08 -2.489109e-08
# 1.987988      -1.673659e-07 -5.065655e-08
# 1.988989      -2.598574e-07 -7.826095e-08
# 1.989990      -3.519822e-07 -1.056748e-07
# 1.990991      -4.348377e-07 -1.302276e-07
# 1.991992      -4.971286e-07 -1.485395e-07
# 1.992993      -5.249245e-07 -1.564510e-07
# 1.993994      -5.014121e-07 -1.489515e-07
# 1.994995      -4.066402e-07 -1.201056e-07
# 1.995996      -2.172588e-07 -6.297839e-08
# 1.996997       9.374977e-08  3.044148e-08
# 1.997998       5.573461e-07  1.693205e-07
# 1.998999       1.208717e-06  3.640605e-07
# 2.000000       2.087564e-06  6.263813e-07
#
# [1000 rows x 2 columns]

# %%
np.abs(solver.residuals).plot(logy=True, alpha=0.5)

# %% [markdown]
# # Example:
#
# Multiplicative separability with log-normal worker skill and firm productivity distributions...

# %%
# define some workers skill
mu1, sigma1 = sym.var('mu1, sigma1')
skill_cdf = 0.5 + 0.5 * sym.erf((sym.log(x) - mu1) / sym.sqrt(2 * sigma1**2))
skill_params = {'mu1': 0.0, 'sigma1': 1.0}
skill_bounds = [1e-2, 1e2]

workers = inputs.Input(var=x,
                       cdf=skill_cdf,
                       params=skill_params,
                       bounds=skill_bounds,
                       )

# define some firms
mu2, sigma2 = sym.var('mu2, sigma2')
productivity_cdf = 0.5 + 0.5 * sym.erf((sym.log(y) - mu2) / sym.sqrt(2 * sigma2**2))
productivity_params = {'mu2': 0.0, 'sigma2': 1.0}
productivity_bounds = [1e-2, 1e2]

firms = inputs.Input(var=y,
                     cdf=productivity_cdf,
                     params=productivity_params,
                     bounds=productivity_bounds,
                     )

# %% [markdown]
# ### Positive assortative matching

# %%
# define symbolic expression for CES between x and y
omega_A, sigma_A = sym.var('omega_A, sigma_A')
A = ((omega_A * x**((sigma_A - 1) / sigma_A) + 
     (1 - omega_A) * y**((sigma_A - 1) / sigma_A))**(sigma_A / (sigma_A - 1))) 

# define symbolic expression for Cobb-Douglas between l and r
l, r, omega_B, sigma_B = sym.var('l, r, omega_B, sigma_B')
B = l**omega_B * r**(1 - omega_B)

F = A * B

F_params = {'omega_A':0.75, 'omega_B':0.25, 'sigma_A':0.95, 'sigma_B':1.0}

model = models.Model('positive',
                     workers=workers,
                     firms=firms,
                     production=F,
                     params=F_params)

solver = shooting.ShootingSolver(model=model)

# %%
solver.solve(1e0, tol=1e-6, number_knots=5000, integrator='lsoda',
             with_jacobian=True, atol=1e-12, rtol=1e-9, message=True)
# Out:
# Exhausted workers: initial guess of 0.5 for firm size is too high!
# Exhausted workers: initial guess of 0.25 for firm size is too high!
# Exhausted workers: initial guess of 0.125 for firm size is too high!
# Exhausted workers: initial guess of 0.0625 for firm size is too high!
# Exhausted workers: initial guess of 0.03125 for firm size is too high!
# Exhausted workers: initial guess of 0.015625 for firm size is too high!
# Exhausted workers: initial guess of 0.0078125 for firm size is too high!
# Exhausted workers: initial guess of 0.00390625 for firm size is too high!
# Exhausted workers: initial guess of 0.001953125 for firm size is too high!
# Exhausted workers: initial guess of 0.0009765625 for firm size is too high!
# Exhausted workers: initial guess of 0.00048828125 for firm size is too high!
# Exhausted workers: initial guess of 0.000244140625 for firm size is too high!
# Exhausted workers: initial guess of 0.0001220703125 for firm size is too high!
# Exhausted workers: initial guess of 6.103515625e-05 for firm size is too high!
# Exhausted workers: initial guess of 3.0517578125e-05 for firm size is too high!
# Exhausted workers: initial guess of 1.52587890625e-05 for firm size is too high!
# Exhausted workers: initial guess of 7.62939453125e-06 for firm size is too high!
# Exhausted workers: initial guess of 3.81469726562e-06 for firm size is too high!
# Exhausted workers: initial guess of 1.90734863281e-06 for firm size is too high!
# Exhausted firms: initial guess of 9.53674316406e-07 for firm size is too low.
# Exhausted firms: initial guess of 1.43051147461e-06 for firm size is too low.
# Exhausted workers: initial guess of 1.66893005371e-06 for firm size is too high!
# Exhausted workers: initial guess of 1.54972076416e-06 for firm size is too high!
# Exhausted firms: initial guess of 1.49011611938e-06 for firm size is too low.
# Exhausted firms: initial guess of 1.51991844177e-06 for firm size is too low.
# Exhausted workers: initial guess of 1.53481960297e-06 for firm size is too high!
# Exhausted firms: initial guess of 1.52736902237e-06 for firm size is too low.
# Exhausted workers: initial guess of 1.53109431267e-06 for firm size is too high!
# Exhausted workers: initial guess of 1.52923166752e-06 for firm size is too high!
# Exhausted workers: initial guess of 1.52830034494e-06 for firm size is too high!
# Exhausted workers: initial guess of 1.52783468366e-06 for firm size is too high!
# Exhausted workers: initial guess of 1.52760185301e-06 for firm size is too high!
# Exhausted workers: initial guess of 1.52748543769e-06 for firm size is too high!
# Exhausted workers: initial guess of 1.52742723003e-06 for firm size is too high!
# Exhausted workers: initial guess of 1.5273981262e-06 for firm size is too high!
# Exhausted firms: initial guess of 1.52738357428e-06 for firm size is too low.
# Exhausted firms: initial guess of 1.52739085024e-06 for firm size is too low.
# Exhausted workers: initial guess of 1.52739448822e-06 for firm size is too high!
# Exhausted workers: initial guess of 1.52739266923e-06 for firm size is too high!
# Exhausted workers: initial guess of 1.52739175974e-06 for firm size is too high!
# Exhausted firms: initial guess of 1.52739130499e-06 for firm size is too low.
# Exhausted firms: initial guess of 1.52739153236e-06 for firm size is too low.
# Exhausted firms: initial guess of 1.52739164605e-06 for firm size is too low.
# Exhausted workers: initial guess of 1.52739170289e-06 for firm size is too high!
# Exhausted firms: initial guess of 1.52739167447e-06 for firm size is too low.
# Exhausted firms: initial guess of 1.52739168868e-06 for firm size is too low.
# Exhausted workers: initial guess of 1.52739169579e-06 for firm size is too high!
# Exhausted workers: initial guess of 1.52739169224e-06 for firm size is too high!
# Exhausted firms: initial guess of 1.52739169046e-06 for firm size is too low.
# Exhausted firms: initial guess of 1.52739169135e-06 for firm size is too low.
# Exhausted firms: initial guess of 1.52739169179e-06 for firm size is too low.
# Exhausted workers: initial guess of 1.52739169201e-06 for firm size is too high!
# Exhausted firms: initial guess of 1.5273916919e-06 for firm size is too low.
# Exhausted workers: initial guess of 1.52739169196e-06 for firm size is too high!
# Exhausted firms: initial guess of 1.52739169193e-06 for firm size is too low.
# Exhausted workers: initial guess of 1.52739169194e-06 for firm size is too high!
# Exhausted workers: initial guess of 1.52739169194e-06 for firm size is too high!
# Exhausted workers: initial guess of 1.52739169193e-06 for firm size is too high!
# Exhausted workers: initial guess of 1.52739169193e-06 for firm size is too high!
# Exhausted workers: initial guess of 1.52739169193e-06 for firm size is too high!
# Exhausted workers: initial guess of 1.52739169193e-06 for firm size is too high!
# Exhausted workers: initial guess of 1.52739169193e-06 for firm size is too high!
# Exhausted workers: initial guess of 1.52739169193e-06 for firm size is too high!
# Exhausted firms: initial guess of 1.52739169193e-06 for firm size is too low.
# Exhausted workers: initial guess of 1.52739169193e-06 for firm size is too high!
# Exhausted workers: initial guess of 1.52739169193e-06 for firm size is too high!
# Exhausted workers: initial guess of 1.52739169193e-06 for firm size is too high!
# Exhausted workers: initial guess of 1.52739169193e-06 for firm size is too high!
# Exhausted firms: initial guess of 1.52739169193e-06 for firm size is too low.
# Exhausted workers: initial guess of 1.52739169193e-06 for firm size is too high!
# Exhausted workers: initial guess of 1.52739169193e-06 for firm size is too high!
# Exhausted workers: initial guess of 1.52739169193e-06 for firm size is too high!
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-114-585ebad95927> in <module>()
#       1 solver.solve(1e0, tol=1e-6, number_knots=5000, integrator='lsoda',
# ----> 2              with_jacobian=True, atol=1e-12, rtol=1e-9, message=True)
#
# /Users/drpugh/Research/assortative-matching-large-firms/shooting.py in solve(self, guess_firm_size_upper, tol, number_knots, integrator, message, **kwargs)
#     348
#     349             guess_firm_size = self._update_initial_guess(firm_size_lower,
# --> 350                                                          firm_size_upper)
#     351
#     352             self._reset_solution(guess_firm_size)
#
# /Users/drpugh/Research/assortative-matching-large-firms/shooting.py in _update_initial_guess(self, lower, upper)
#     200         """Use bisection method to arrive at new initial guess."""
#     201         err_mesg = 'Upper and lower bounds are identical: check solver tols!'
# --> 202         assert (upper - lower) / upper > np.finfo('float').eps, err_mesg
#     203         guess = 0.5 * (lower + upper)
#     204         return guess
#
# AssertionError: Upper and lower bounds are identical: check solver tols!

# %%
solver.solution
# Out:
#              firm productivity     firm size          wage     profit
# x
# 0.001000              0.001337  3.152535e+09  2.019923e-11   0.191036
# 0.201040              0.016028  1.416287e+03  1.120078e-04   0.475906
# 0.401080              0.031976  2.469037e+02  8.282561e-04   0.613498
# 0.601119              0.047924  8.873082e+01  2.674451e-03   0.711919
# 0.801159              0.063872  4.290807e+01  6.146735e-03   0.791234
# 1.001199              0.079821  2.441802e+01  1.172378e-02   0.858814
# 1.201239              0.095769  1.540387e+01  1.987179e-02   0.918307
# 1.401279              0.111717  1.043374e+01  3.104735e-02   0.971820
# 1.601318              0.127665  7.445021e+00  4.569918e-02   1.020694
# 1.801358              0.143614  5.528003e+00  6.426937e-02   1.065844
# 999.559992          292.622545  1.003563e-06  5.746613e+06  17.301304
# 999.579992          293.828805  1.005646e-06  5.746952e+06  17.338221
# 999.599992          294.661175  1.007540e-06  5.747291e+06  17.371885
# 999.619993          295.188981  1.009298e-06  5.747631e+06  17.403184
# 999.639993          295.540288  1.011009e-06  5.747970e+06  17.433686
# 999.659994          295.910661  1.012810e-06  5.748309e+06  17.465745
# 999.679994          296.571926  1.014888e-06  5.748649e+06  17.502593
# 999.699994          297.880940  1.017488e-06  5.748989e+06  17.548448
# 999.719995          300.288349  1.020916e-06  5.749328e+06  17.608611
# 999.739995          304.347357  1.025549e-06  5.749668e+06  17.689570
# 999.759995          310.722487  1.031836e-06  5.750008e+06  17.799097
# 999.779996          320.198344  1.040309e-06  5.750348e+06  17.946352
# 999.799996          333.688382  1.051583e-06  5.750688e+06  18.141980
# 999.819997          352.243667  1.066368e-06  5.751028e+06  18.398216
# 999.839997          377.061640  1.085470e-06  5.751368e+06  18.728984
# 999.859997          409.494880  1.109799e-06  5.751709e+06  19.149998
# 999.879998          451.059871  1.140375e-06  5.752049e+06  19.678861
# 999.899998          503.445764  1.178333e-06  5.752390e+06  20.335168
# 999.919998          568.523140  1.224930e-06  5.752731e+06  21.140606
# 999.939999          648.352778  1.281548e-06  5.753072e+06  22.119056
# 999.959999          745.194413  1.349704e-06  5.753414e+06  23.296691
# 999.980000          861.515505  1.431052e-06  5.753755e+06  24.702078
# 1000.000000        1000.000000  1.527392e-06  5.754097e+06  26.366281
#
# [50000 rows x 4 columns]

# %%
solver.interpolated_solution.plot(loglog=True)

# %%
(np.abs(solver.residuals) / solver.interpolated_solution[['firm productivity', 'firm size']]).plot(loglog=True)

# %%
np.abs(solver.residuals).plot(logy=True, alpha=0.5)

# %% [markdown]
# ### Negative assortative matching

# %%
# define some workers skill
mu1, sigma1 = sym.var('mu1, sigma1')
skill_cdf = 0.5 + 0.5 * sym.erf((sym.log(x) - mu1) / sym.sqrt(2 * sigma1**2))
skill_params = {'mu1': 0.0, 'sigma1': 1.0}
skill_bounds = [1e-3, 1e3]

workers = inputs.Input(var=x,
                       cdf=skill_cdf,
                       params=skill_params,
                       bounds=skill_bounds,
                       )

# define some firms
mu2, sigma2 = sym.var('mu2, sigma2')
productivity_cdf = 0.5 + 0.5 * sym.erf((sym.log(y) - mu2) / sym.sqrt(2 * sigma2**2))
productivity_params = {'mu2': 0.0, 'sigma2': 1.0}
productivity_bounds = [1e-3, 1e3]

omega_A, sigma_A = sym.var('omega_A, sigma_A')
A = ((omega_A * x**((sigma_A - 1) / sigma_A) + 
     (1 - omega_A) * y**((sigma_A - 1) / sigma_A))**(sigma_A / (sigma_A - 1))) 

# define symbolic expression for Cobb-Douglas between l and r
l, r, omega_B, sigma_B = sym.var('l, r, omega_B, sigma_B')
B = l**omega_B * r**(1 - omega_B)

F = A * B

firms = inputs.Input(var=y,
                     cdf=productivity_cdf,
                     params=productivity_params,
                     bounds=productivity_bounds,
                     )
F_params = {'omega_A':0.25, 'omega_B':0.75, 'sigma_A':1.5, 'sigma_B':1.0}

model = models.Model('negative',
                     workers=workers,
                     firms=firms,
                     production=F,
                     params=F_params)

solver = shooting.ShootingSolver(model=model)

# %%
solver.solve(1e9, tol=1e-3, number_knots=10000, integrator='dop853',
             atol=1e-12, rtol=1e-9, message=True)
# Out:
# Exhausted workers: initial guess of 500000000.0 for firm size is too high!
# Exhausted workers: initial guess of 250000000.0 for firm size is too high!

# %%
solver.solution
# Out:
#           firm productivity     firm size      wage        profit
# x
# 0.001000        1000.000000  1.220703e+08  3.040383  1.237135e+08
# 0.101010         348.057094  1.813997e+06  3.203886  1.937280e+06
# 0.201020         156.824015  7.964676e+04  3.286307  8.724790e+04
# 0.301030          93.485533  1.070454e+04  3.358928  1.198526e+04
# 0.401040          62.358554  2.261469e+03  3.426909  2.583282e+03
# 0.501050          43.873790  5.949377e+02  3.492500  6.926067e+02
# 0.601059          31.549225  1.725873e+02  3.557111  2.046374e+02
# 0.701069          22.608750  5.027735e+01  3.621914  6.070008e+01
# 0.801079          15.615638  1.307599e+01  3.688232  1.607576e+01
# 0.901089           9.592070  2.312030e+00  3.758238  2.896386e+00
# 1.001099           2.073143  1.383323e-02  3.839895  1.770605e-02
# 1.005032           0.006514  1.820565e-08  3.844460  2.333030e-08

# %%
solver.solution.plot(loglog=True)

# %%
solver.residuals
# Out:
#              firm productivity     firm size
# x
# 0.001000         -21360.843509 -1.166961e+05
# 0.011000         214057.758160  3.088759e+07
# 0.021000         401017.639649  5.436097e+07
# 0.031000         253834.218544  3.293469e+07
# 0.041000         105415.023097  1.306172e+07
# 0.051000          33420.559949  3.962162e+06
# 0.061001           7235.487420  8.515208e+05
# 0.071001           -582.343742 -1.500115e+04
# 0.081001          -2282.917310 -1.906684e+05
# 0.091001          -2167.530698 -1.825196e+05
# 0.101001          -1377.194759 -1.356549e+05
# 0.111001          -1528.692672           NaN
# 0.121001           -902.538148           NaN
# 0.131001           -504.495586           NaN
# 0.141001           -222.017062           NaN
# 0.151001            -30.112645           NaN
# 0.161001             87.439341           NaN
# 0.171002            142.915230           NaN
# 0.181002            140.699615           NaN
# 0.191002              8.851732           NaN
# 0.201002            284.585456  2.722496e+04
# 0.211002            139.882543  2.117810e+04
# 0.221002             60.188497  1.452769e+04
# 0.231002             -9.114354  7.869441e+03
# 0.241002            -69.840184  1.705493e+03
# 0.251002           -119.557593 -3.560794e+03
# 0.261002           -155.690539 -7.634711e+03
# 0.271002           -176.322869 -1.034026e+04
# 0.281003           -180.110417 -1.162676e+04
# 0.291003           -164.598168 -1.157104e+04
# ...                        ...           ...
# 999.709997           -0.000107 -5.251048e-09
# 999.719997           -0.000107 -5.270074e-09
# 999.729998           -0.000093 -4.680108e-09
# 999.739998           -0.000067 -3.448820e-09
# 999.749998           -0.000028 -1.600698e-09
# 999.759998            0.000021  7.840911e-10
# 999.769998            0.000078  3.571220e-09
# 999.779998            0.000139  6.574180e-09
# 999.789998            0.000199  9.556799e-09
# 999.799998            0.000251  1.223641e-08
# 999.809998            0.000290  1.428778e-08
# 999.819998            0.000308  1.534815e-08
# 999.829998            0.000296  1.502359e-08
# 999.839999            0.000247  1.289776e-08
# 999.849999            0.000153  8.544066e-09
# 999.859999            0.000006  1.543752e-09
# 999.869999           -0.000201 -8.486052e-09
# 999.879999           -0.000471 -2.184704e-08
# 999.889999           -0.000806 -3.868363e-08
# 999.899999           -0.001199 -5.884973e-08
# 999.909999           -0.001630 -8.166544e-08
# 999.919999           -0.002056 -1.054491e-07
# 999.929999           -0.002392 -1.265619e-07
# 999.939999           -0.002463 -1.373110e-07
# 999.950000           -0.001906 -1.209235e-07
# 999.960000            0.000097 -3.809962e-08
# 999.970000            0.005592  2.143550e-07
# 999.980000            0.020557  9.566089e-07
# 999.990000            0.066930  3.457784e-06
# 1000.000000           0.259280  1.507616e-05
#
# [100000 rows x 2 columns]

# %%
np.abs(solver.residuals).plot(logy=True, alpha=0.5)

# %% [markdown]
# # Example:
#
# More sophisticated production function that is not multiplicatively separable...

# %%
# define some workers skill
x, mu1, sigma1 = sym.var('x, mu1, sigma1')
skill_cdf = 0.5 + 0.5 * sym.erf((sym.log(x) - mu1) / sym.sqrt(2 * sigma1**2))
skill_params = {'mu1': 0.0, 'sigma1': 1e0}
skill_bounds = [1e-2, 1e2]

workers = inputs.Input(var=x,
                       cdf=skill_cdf,
                       params=skill_params,
                       bounds=skill_bounds,
                       )

# define some firms
y, mu2, sigma2 = sym.var('y, mu2, sigma2')
productivity_cdf = 0.5 + 0.5 * sym.erf((sym.log(y) - mu2) / sym.sqrt(2 * sigma2**2))
productivity_params = {'mu2': 0.0, 'sigma2': 1e0}
productivity_bounds = [1e-2, 1e2]

firms = inputs.Input(var=y,
                     cdf=productivity_cdf,
                     params=productivity_params,
                     bounds=productivity_bounds,
                     )

# define some valid model params
F_params = {'eta': 0.89, 'kappa': 1.0, 'gamma': 0.54, 'rho': 0.24, 'A': 1.0, 'k': 1.0}

# define a valid production function
A, k, kappa, eta, rho, l, gamma, r = sym.var('A, k, kappa, eta, rho, l, gamma, r')
F = r * A * kappa * eta * ((k * x)**rho + (1 - eta) * (y * (l / r))**rho)**(gamma / rho)

model = models.Model('negative',
                     workers=workers,
                     firms=firms,
                     production=F,
                     params=F_params)

# %%
solver = shooting.ShootingSolver(model=model)

# %%
solver.solve(1e6, tol=1e-3, number_knots=5000, integrator='dopri5',
             atol=1e-12, rtol=1e-9, message=True)
# Out:
# Exhausted workers: initial guess of 500000.0 for firm size is too high!
# Exhausted workers: initial guess of 250000.0 for firm size is too high!
# Exhausted workers: initial guess of 125000.0 for firm size is too high!
# Exhausted firms: initial guess of 62500.0 for firm size is too low.
# Exhausted workers: initial guess of 93750.0 for firm size is too high!
# Exhausted firms: initial guess of 78125.0 for firm size is too low.
# Exhausted workers: initial guess of 85937.5 for firm size is too high!
# Exhausted firms: initial guess of 82031.25 for firm size is too low.
# Exhausted workers: initial guess of 83984.375 for firm size is too high!
# Exhausted firms: initial guess of 83007.8125 for firm size is too low.
# Exhausted firms: initial guess of 83496.09375 for firm size is too low.
# Exhausted firms: initial guess of 83740.234375 for firm size is too low.
# Exhausted workers: initial guess of 83862.3046875 for firm size is too high!
# Exhausted workers: initial guess of 83801.2695312 for firm size is too high!
# Exhausted workers: initial guess of 83770.7519531 for firm size is too high!
# Exhausted firms: initial guess of 83755.4931641 for firm size was too low!
# Exhausted firms: initial guess of 83763.1225586 for firm size was too low!
# Exhausted workers: initial guess of 83766.9372559 for firm size is too high!
# Exhausted workers: initial guess of 83765.0299072 for firm size is too high!
# Exhausted firms: initial guess of 83764.0762329 for firm size was too low!
# Exhausted firms: initial guess of 83764.5530701 for firm size was too low!
# Exhausted firms: initial guess of 83764.7914886 for firm size was too low!
# Exhausted firms: initial guess of 83764.9106979 for firm size was too low!
# Exhausted workers: initial guess of 83764.9703026 for firm size is too high!
# Exhausted workers: initial guess of 83764.9405003 for firm size is too high!
# Exhausted firms: initial guess of 83764.9255991 for firm size was too low!
# Exhausted firms: initial guess of 83764.9330497 for firm size was too low!
# Exhausted firms: initial guess of 83764.936775 for firm size was too low!
# Exhausted firms: initial guess of 83764.9386376 for firm size was too low!
# Exhausted firms: initial guess of 83764.9395689 for firm size was too low!
# Exhausted workers: initial guess of 83764.9400346 for firm size is too high!
# Exhausted firms: initial guess of 83764.9398018 for firm size was too low!
# Exhausted workers: initial guess of 83764.9399182 for firm size is too high!
# Exhausted workers: initial guess of 83764.93986 for firm size is too high!
# Exhausted workers: initial guess of 83764.9398309 for firm size is too high!
# Exhausted firms: initial guess of 83764.9398163 for firm size was too low!
# Exhausted firms: initial guess of 83764.9398236 for firm size was too low!
# Exhausted workers: initial guess of 83764.9398272 for firm size is too high!
# Exhausted workers: initial guess of 83764.9398254 for firm size is too high!
# Exhausted workers: initial guess of 83764.9398245 for firm size is too high!
# Success! All workers and firms are matched

# %%
solver.solution
# Out:
#            firm productivity     firm size           wage     profit
# x
# 0.010000          100.000000  8.376494e+04       0.000237  19.326771
# 0.030002           99.970172  7.386098e+04       0.000258  19.321035
# 0.050004           99.807695  6.860303e+04       0.000270  19.290554
# 0.070006           99.428551  6.478157e+04       0.000280  19.220773
# 0.090008           98.802805  6.163299e+04       0.000289  19.107376
# 0.110010           97.941115  5.886610e+04       0.000296  18.953254
# 0.130012           96.877773  5.635129e+04       0.000302  18.765229
# 0.150014           95.657334  5.402687e+04       0.000308  18.551615
# 0.170016           94.325533  5.186192e+04       0.000314  18.320649
# 0.190018           92.923965  4.983945e+04       0.000319  18.079622
# 0.210020           91.487623  4.794858e+04       0.000324  17.834521
# 0.230022           90.044284  4.618083e+04       0.000329  17.589989
# 0.250024           88.614975  4.452854e+04       0.000334  17.349448
# 0.270026           87.214916  4.298429e+04       0.000338  17.115299
# 0.290028           85.854608  4.154073e+04       0.000343  16.889132
