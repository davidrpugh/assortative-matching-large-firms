# %%
# %load_ext autoreload

# %%
autoreload 2

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy as sym

import inputs
import models
import shooting

# %% [markdown]
# # Example:
#
# ## Worker skill and firm productivity are $\sim U[a, b]$...

# %%
# define some workers skill
x, a, b = sym.var('x, a, b')
skill_cdf = (x - a) / (b - a)
skill_params = {'a': 1.0, 'b': 2.0}
skill_bounds = [skill_params['a'], skill_params['b']]

workers = inputs.Input(var=x,
                       cdf=skill_cdf,
                       params=skill_params,
                       bounds=skill_bounds,
                       )

# define some firms
y = sym.var('y')
productivity_cdf = (y - a) / (b - a)
productivity_params = skill_params
productivity_bounds = skill_bounds

firms = inputs.Input(var=y,
                     cdf=productivity_cdf,
                     params=productivity_params,
                     bounds=productivity_bounds,
                     )

# %% [markdown]
# ## ...and production function is multiplicatively separable.
# A particularly attractive case arises under multiplicative separability of the form
#
# $$F(x, y, l, r) = A(x, y)B(l, r)$$
#
# In this case the condition for positive assortative matching can be written as
#
# $$\frac{AA_{xy}}{A_xA_y}\frac{BB_{lr}}{B_lB_r} \ge 1$$
#
# If $B$ has constant elasticity of substitution form, then we obtain an even simpler condition
#
# $$\frac{AA_{xy}}{A_xA_y} \frac{1}{\sigma_{lr}}\ge 1$$
#
# where $\sigma_{lr}$ is the elasticity of substitution between $l$ and $r$.
#
# Finally, if $A$ also has constant elasticity of substitution form, then we obtain an even simpler condition
#
# $$\frac{1}{\sigma_{xy}\sigma_{lr}}\ge 1 \iff \sigma_{xy}\sigma_{lr} \le 1$$
#
# where $\sigma_{xy}$ is the elasticity of substitution between $x$ and $y$.

# %%
# define symbolic expression for CES between x and y
omega_A, sigma_A = sym.var('omega_A, sigma_A')
A = ((omega_A * x**((sigma_A - 1) / sigma_A) + 
     (1 - omega_A) * y**((sigma_A - 1) / sigma_A))**(sigma_A / (sigma_A - 1))) 

# define symbolic expression for Cobb-Douglas between l and r
l, r, omega_B, sigma_B = sym.var('l, r, omega_B, sigma_B')
B = l**omega_B * r**(1 - omega_B)

F = A * B

# %% [markdown]
# Create an instance of the `models.Model` class and an instance of the `solvers.ShootingSolver` class...

# %% [markdown]
# ### Positive assortative matching

# %%
F_params = {'omega_A':0.5, 'omega_B':0.45, 'sigma_A':0.95, 'sigma_B':1.0}

model = models.Model(assortativity='positive',
                     workers=workers,
                     firms=firms,
                     production=F,
                     params=F_params)

solver = shooting.ShootingSolver(model=model)

# %%
solver.solve(1e1, tol=1e-6, number_knots=100, atol=1e-15, rtol=1e-12)
# Out:
# Success! All workers and firms are matched

# %%
# examine the solution attribute
solver.solution
# Out:
#           firm productivity  firm size      wage    profit
# x
# 1.000000           0.999999   1.089348  0.429310  0.571594
# 1.010101           1.009285   1.086340  0.434131  0.576417
# 1.020202           1.018595   1.083403  0.438957  0.581249
# 1.030303           1.027931   1.080534  0.443788  0.586090
# 1.040404           1.037292   1.077730  0.448625  0.590940
# 1.050505           1.046676   1.074990  0.453467  0.595799
# 1.060606           1.056084   1.072310  0.458313  0.600666
# 1.070707           1.065516   1.069689  0.463165  0.605541
# 1.080808           1.074970   1.067126  0.468022  0.610425
# 1.090909           1.084447   1.064617  0.472884  0.615316
# 1.005005      -2.992995e-11 -8.102991e-10
# 1.006006      -3.890732e-11 -1.006469e-09
# 1.007007      -4.198863e-11 -1.059098e-09
# 1.008008      -4.070588e-11 -1.007436e-09
# 1.009009      -3.637857e-11 -8.848456e-10
# 1.010010      -3.012290e-11 -7.192120e-10
# 1.011011      -2.286793e-11 -5.333611e-10
# 1.012012      -1.536515e-11 -3.454707e-10
# 1.013013      -8.203216e-12 -1.694784e-10
# 1.014014      -1.821765e-12 -1.549233e-11
# 1.015015       3.478218e-12  1.098107e-10
# 1.016016       7.515322e-12  2.027748e-10
# 1.017017       1.021749e-11  2.623724e-10
# 1.018018       1.160694e-11  2.898046e-10
# 1.019019       1.178391e-11  2.881079e-10
# 1.020020       1.091327e-11  2.617593e-10
# 1.021021       9.207968e-12  2.162875e-10
# 1.022022       6.915135e-12  1.578896e-10
# 1.023023       4.298339e-12  9.303902e-11
# 1.024024       1.622924e-12  2.810879e-11
# 1.025025      -8.603118e-13 -3.101258e-11
# 1.026026      -2.932210e-12 -7.929518e-11
# 1.027027      -4.422018e-12 -1.129482e-10
# 1.028028      -5.225709e-12 -1.297907e-10
# 1.029029      -5.319856e-12 -1.296222e-10
# ...                     ...           ...
# 1.970971       1.536549e-13  8.288092e-13
# 1.971972       1.318945e-13  8.264778e-13
# 1.972973       8.992806e-14  7.152612e-13
# 1.973974       2.908784e-14  4.969219e-13
# 1.974975      -4.862777e-14  1.848244e-13
# 1.975976      -1.354472e-13 -1.955935e-13
# 1.976977      -2.258194e-13 -6.120521e-13
# 1.977978      -3.115286e-13 -1.026901e-12
# 1.978979      -3.848033e-13 -1.398950e-12
# 1.979980      -4.354295e-13 -1.686887e-12
# 1.980981      -4.574119e-13 -1.851366e-12
# 1.981982      -4.436451e-13 -1.857764e-12
# 1.982983      -3.883560e-13 -1.678033e-12
# 1.983984      -2.886580e-13 -1.294020e-12
# 1.984985      -1.436629e-13 -6.981221e-13
# 1.985986       4.374279e-14  1.012801e-13
# 1.986987       2.675637e-13  1.080122e-12
# 1.987988       5.186962e-13  2.195646e-12
# 1.988989       7.822631e-13  3.383113e-12
# 1.989990       1.038503e-12  4.553705e-12
# 1.990991       1.262768e-12  5.592707e-12
# 1.991992       1.423306e-12  6.356971e-12
# 1.992993       1.483702e-12  6.672080e-12
# 1.993994       1.397549e-12  6.329895e-12
# 1.994995       1.113776e-12  5.087833e-12
# 1.995996       5.724310e-13  2.664341e-12
# 1.996997      -2.968736e-13 -1.263156e-12
# 1.997998      -1.570966e-12 -7.058340e-12
# 1.998999      -3.338885e-12 -1.513170e-11
# 2.000000      -5.698109e-12 -2.593938e-11
#
# [1000 rows x 2 columns]

# %%
np.abs(solver.residuals).plot(logy=True, alpha=0.5)

# %% [markdown]
# ### Negative assortative matching

# %%
# negative assortativity requires that sigma_A * sigma_B > 1
F_params = {'omega_A':0.25, 'omega_B':0.5, 'sigma_A':1.5, 'sigma_B':1.0}

# %%
model = models.Model(assortativity='negative',
                     workers=workers,
                     firms=firms,
                     production=F,
                     params=F_
# 1.992993      -5.249245e-07 -1.564510e-07
# 1.993994      -5.014121e-07 -1.489515e-07
# 1.994995      -4.066402e-07 -1.201056e-07
# 1.995996      -2.172588e-07 -6.297839e-08
# 1.996997       9.374977e-08  3.044148e-08
# 1.997998       5.573461e-07  1.693205e-07
# 1.998999       1.208717e-06  3.640605e-07
# 2.000000       2.087564e-06  6.263813e-07
#
# [1000 rows x 2 columns]

# %%
np.abs(solver.residuals).plot(logy=True, alpha=0.5)

# %% [markdown]
# # Example:
#
# Multiplicative separability with log-normal worker skill and firm productivity distributions...

# %%
# define some workers skill
mu1, sigma1 = sym.var('mu1, sigma1')
skill_cdf = 0.5 + 0.5 * sym.erf((sym.log(x) - mu1) / sym.sqrt(2 * sigma1**2))
skill_params = {'mu1': 0.0, 'sigma1': 1.0}
skill_bounds = [1e-2, 1e2]

workers = inputs.Input(var=x,
                       cdf=skill_cdf,
                       params=skill_params,
                       bounds=skill_bounds,
                       )

# define some firms
mu2, sigma2 = sym.var('mu2, sigma2')
productivity_cdf = 0.5 + 0.5 * sym.erf((sym.log(y) - mu2) / sym.sqrt(2 * sigma2**2))
productivity_params = {'mu2': 0.0, 'sigma2': 1.0}
productivity_bounds = [1e-2, 1e2]

firms = inputs.Input(var=y,
                     cdf=productivity_cdf,
                     params=productivity_params,
                     bounds=productivity_bounds,
                     )

# %% [markdown]
# ### Positive assortative matching

# %%
# define symbolic expression for CES between x and y
omega_A, sigma_A = sym.var('omega_A, sigma_A')
A = ((omega_A * x**((sigma_A - 1) / sigma_A) + 
     (1 - omega_A) * y**((sigma_A - 1) / sigma_A))**(sigma_A / (sigma_A - 1))) 

# define symbolic expression for Cobb-Douglas between l and r
l, r, omega_B, sigma_B = sym.var('l, r, omega_B, sigma_B')
B = l**omega_B * r**(1 - omega_B)

F = A * B

F_params = {'omega_A':0.5, 'omega_B':0.45, 'sigma_A':0.5, 'sigma_B':1.0}

model = models.Model('positive',
                     workers=workers,
                     firms=firms,
                     production=F,
                     params=F_params)

solver = shooting.ShootingSolver(model=model)

# %%
solver.solve(1e0, tol=1e-3, number_knots=1000, integrator='lsoda',
             with_jacobian=True, atol=1e-12, rtol=1e-9, message=True)
# Out:
# Exhausted firms: initial guess of 0.5 for firm size is too low.
# Exhausted workers: initial guess of 0.75 for firm size is too high!
# Exhausted firms: initial guess of 0.625 for firm size is too low.
# Exhausted workers: initial guess of 0.6875 for firm size is too high!
# Exhausted firms: initial guess of 0.65625 for firm size is too low.
# Exhausted firms: initial guess of 0.671875 for firm size is too low.
# Exhausted workers: initial guess of 0.6796875 for firm size is too high!
# Exhausted firms: initial guess of 0.67578125 for firm size is too low.
# Exhausted workers: initial guess of 0.677734375 for firm size is too high!
# Exhausted firms: initial guess of 0.6767578125 for firm size is too low.
# Exhausted workers: initial guess of 0.67724609375 for firm size is too high!
# Exhausted firms: initial guess of 0.677001953125 for firm size is too low.
# Exhausted workers: initial guess of 0.677124023438 for firm size is too high!
# Exhausted firms: initial guess of 0.677062988281 for firm size is too low.
# Exhausted workers: initial guess of 0.677093505859 for firm size is too high!
# Exhausted workers: initial guess of 0.67707824707 for firm size is too high!
# Exhausted workers: initial guess of 0.677070617676 for firm size is too high!
# Exhausted workers: initial guess of 0.677066802979 for firm size is too high!
# Exhausted firms: initial guess of 0.67706489563 for firm size is too low.
# Exhausted firms: initial guess of 0.677065849304 for firm size is too low.
# Exhausted workers: initial guess of 0.677066326141 for firm size is too high!
# Exhausted workers: initial guess of 0.677066087723 for firm size is too high!
# Exhausted workers: initial guess of 0.677065968513 for firm size is too high!
# Exhausted firms: initial guess of 0.677065908909 for firm size is too low.
# Exhausted workers: initial guess of 0.677065938711 for firm size is too high!
# Exhausted firms: initial guess of 0.67706592381 for firm size is too low.
# Exhausted firms: initial guess of 0.677065931261 for firm size is too low.
# Exhausted firms: initial guess of 0.677065934986 for firm size is too low.
# Exhausted firms: initial guess of 0.677065936849 for firm size is too low.
# Exhausted workers: initial guess of 0.67706593778 for firm size is too high!
# Exhausted firms: initial guess of 0.677065937314 for firm size was too low!
# Exhausted workers: initial guess of 0.677065937547 for firm size is too high!
# Exhausted firms: initial guess of 0.677065937431 for firm size was too low!
# Exhausted firms: initial guess of 0.677065937489 for firm size was too low!
# Exhausted workers: initial guess of 0.677065937518 for firm size is too high!
# Exhausted firms: initial guess of 0.677065937503 for firm size was too low!
# Exhausted workers: initial guess of 0.677065937511 for firm size is too high!
# Success! All workers and firms are matched

# %%
solver.solution
# Out:
#             firm productivity  firm size       wage     profit
# x
# 0.010000             0.009998   1.790163   0.003266   0.007147
# 0.110090             0.099560   1.254706   0.041532   0.063690
# 0.210180             0.190076   1.175719   0.082178   0.118089
# 0.310270             0.280592   1.130567   0.123953   0.171279
# 0.410360             0.371108   1.099227   0.166494   0.223685
# 0.510450             0.461624   1.075368   0.209618   0.275509
# 0.610541             0.552141   1.056181   0.253215   0.326873
# 0.710631             0.642658   1.040182   0.297211   0.377855
# 0.810721             0.733174   1.026492   0.341553   0.428512
# 0.910811             0.823691   1.014547   0.386198   0.478887
# 1.010901             0.914208   1.003967   0.431117   0.529011
# 1.110991             1.004725   0.994482   0.476282   0.578911
# 1.211081             1.095242   0.985894   0.521674   0.628607
# 1.311171             1.185759   0.978054   0.567273   0.678118
# 1.411261             1.276276   0.970846   0.613066   0.727458
# 1.511351             1.366793   0.964181   0.659039   0.776640
# 1.611441             1.457311   0.957984   0.705181   0.825674
# 1.711532             1.547828   0.952197   0.751481   0.874571
# 1.811622             1.638346   0.946772   0.797932   0.923339
# 1.911712             1.728864   0.941666   0.844525   0.971985
# 2.011802             1.819382   0.936847   0.891253   1.020516
# 2.111892             1.909900   0.932285   0.938109   1.068937
# 2.211982             2.000418   0.927954   0.985089   1.117255
# 2.312072             2.090937   0.923835   1.032187   1.165475
# 2.412162             2.181455   0.919907   1.079398   1.213599
# 2.512252             2.271974   0.916154   1.126717   1.261634
# 2.612342             2.362493   0.912562   1.174140   1.309582
# 2.712432             2.453012   0.909119   1.221665   1.357447
# 2.812523             2.543531   0.905813   1.269286   1.405233
# 2.912613             2.634050   0.902634   1.317001   1.452941
# ...                       ...        ...        ...        ...
# 97.097387           95.854301   0.673017  53.975759  44.399182
# 97.197477           95.992867   0.673141  54.037192  44.457896
# 97.297568           96.131727   0.673266  54.098644  44.516716
# 97.397658           96.270881   0.673392  54.160116  44.575641
# 97.497748           96.410333   0.673519  54.221607  44.634672
# 97.597838           96.550084   0.673647  54.283118  44.693810
# 97.697928           96.690137   0.673776  54.344649  44.753056
# 97.798018           96.830494   0.673907  54.406200  44.812411
# 97.898108           96.971158   0.674038  54.467770  44.871875
# 97.998198           97.112129   0.674171  54.529361  44.931449
# 98.098288           97.253411   0.674304  54.590971  44.991134
# 98.198378           97.395007   0.674439  54.652602  45.050931
# 98.298468           97.536917   0.674575  54.714253  45.110840
# 98.398559           97.679145   0.674712  54.775924  45.170863
# 98.498649           97.821694   0.674850  54.837615  45.230999
# 98.598739           97.964564   0.674990  54.899327  45.291251
# 98.698829           98.107759   0.675130  54.961060  45.351619
# 98.798919           98.251282   0.675272  55.022813  45.412103
# 98.899009           98.395134   0.675415  55.084586  45.472705
# 98.999099           98.539319   0.675559  55.146381  45.533425
# 99.099189           98.683838   0.675704  55.208196  45.594265
# 99.199279           98.828695   0.675850  55.270032  45.655224
# 99.299369           98.973891   0.675998  55.331889  45.716305
# 99.399459           99.119429   0.676147  55.393768  45.777508
# 99.499550           99.265313   0.676297  55.455667  45.838833
# 99.599640           99.411544   0.676448  55.517588  45.900282
# 99.699730           99.558126   0.676601  55.579530  45.961856
# 99.799820           99.705061   0.676755  55.641493  46.023555
# 99.899910           99.852351   0.676910  55.703478  46.085381
# 100.000000         100.000000   0.677066  55.765485  46.147335
#
# [1000 rows x 4 columns]

# %%
solver.solution.plot(loglog=True)

# %%
np.abs(solver.residuals).plot(logy=True, alpha=0.5)

# %% [markdown]
# ### Negative assortative matching

# %%
# define some workers skill
mu1, sigma1 = sym.var('mu1, sigma1')
skill_cdf = 0.5 + 0.5 * sym.erf((sym.log(x) - mu1) / sym.sqrt(2 * sigma1**2))
skill_params = {'mu1': 0.0, 'sigma1': 1.0}
skill_bounds = [1e-3, 1e2]

workers = inputs.Input(var=x,
                       cdf=skill_cdf,
                       params=skill_params,
                       bounds=skill_bounds,
                       )

# define some firms
mu2, sigma2 = sym.var('mu2, sigma2')
productivity_cdf = 0.5 + 0.5 * sym.erf((sym.log(y) - mu2) / sym.sqrt(2 * sigma2**2))
productivity_params = {'mu2': 0.0, 'sigma2': 1.0}
productivity_bounds = [1e-3, 1e2]

firms = inputs.Input(var=y,
                     cdf=productivity_cdf,
                     params=productivity_params,
                     bounds=productivity_bounds,
                     )
F_params = {'omega_A':0.5, 'omega_B':0.45, 'sigma_A':1.5, 'sigma_B':1.0}

model = models.Model('negative',
                     workers=workers,
                     firms=firms,
                     production=F,
                     params=F_params)

solver = shooting.ShootingSolver(model=model)

# %%
solver.solve(2e3, tol=1e-6, number_knots=5000, integrator='lsoda',
             with_jacobian=True, atol=1e-12, rtol=1e-9, message=True)
# Out:
# Exhausted firms: initial guess of 1000.0 for firm size is too low.
# Exhausted firms: initial guess of 1500.0 for firm size is too low.
# Exhausted workers: initial guess of 1750.0 for firm size is too high!
# Exhausted firms: initial guess of 1625.0 for firm size is too low.
# Exhausted firms: initial guess of 1687.5 for firm size is too low.
# Exhausted workers: initial guess of 1718.75 for firm size is too high!
# Exhausted workers: initial guess of 1703.125 for firm size is too high!
# Exhausted firms: initial guess of 1695.3125 for firm size is too low.
# Exhausted firms: initial guess of 1699.21875 for firm size is too low.
# Exhausted firms: initial guess of 1701.171875 for firm size is too low.
# Exhausted firms: initial guess of 1702.1484375 for firm size is too low.
# Exhausted firms: initial guess of 1702.63671875 for firm size is too low.
# Exhausted firms: initial guess of 1702.88085938 for firm size is too low.
# Exhausted firms: initial guess of 1703.00292969 for firm size is too low.
# Exhausted firms: initial guess of 1703.06396484 for firm size is too low.
# Exhausted firms: initial guess of 1703.09448242 for firm size is too low.
# Exhausted firms: initial guess of 1703.10974121 for firm size is too low.
# Exhausted firms: initial guess of 1703.11737061 for firm size is too low.
# Exhausted workers: initial guess of 1703.1211853 for firm size is too high!
# Exhausted firms: initial guess of 1703.11927795 for firm size is too low.
# Exhausted workers: initial guess of 1703.12023163 for firm size is too high!
# Exhausted workers: initial guess of 1703.11975479 for firm size is too high!
# Exhausted firms: initial guess of 1703.11951637 for firm size is too low.
# Exhausted workers: initial guess of 1703.11963558 for firm size is too high!
# Exhausted workers: initial guess of 1703.11957598 for firm size is too high!
# Exhausted firms: initial guess of 1703.11954618 for firm size is too low.
# Exhausted workers: initial guess of 1703.11956108 for firm size is too high!
# Exhausted firms: initial guess of 1703.11955363 for firm size was too low!
# Exhausted workers: initial guess of 1703.11955735 for firm size is too high!
# Exhausted workers: initial guess of 1703.11955549 for firm size is too high!
# Exhausted firms: initial guess of 1703.11955456 for firm size was too low!
# Exhausted workers: initial guess of 1703.11955502 for firm size is too high!
# Exhausted workers: initial guess of 1703.11955479 for firm size is too high!
# Exhausted firms: initial guess of 1703.11955467 for firm size was too low!
# Exhausted workers: initial guess of 1703.11955473 for firm size is too high!
# Exhausted workers: initial guess of 1703.1195547 for firm size is too high!
# Exhausted workers: initial guess of 1703.11955469 for firm size is too high!
# Exhausted firms: initial guess of 1703.11955468 for firm size was too low!
# Exhausted workers: initial guess of 1703.11955468 for firm size is too high!
# Exhausted firms: initial guess of 1703.11955468 for firm size was too low!
# Exhausted firms: initial guess of 1703.11955468 for firm size was too low!
# Exhausted firms: initial guess of 1703.11955468 for firm size was too low!
# Exhausted workers: initial guess of 1703.11955468 for firm size is too high!
# Exhausted workers: initial guess of 1703.11955468 for firm size is too high!
# Exhausted workers: initial guess of 1703.11955468 for firm size is too high!
# Exhausted workers: initial guess of 1703.11955468 for firm size is too high!
# Exhausted firms: initial guess of 1703.11955468 for firm size was too low!
# Exhausted firms: initial guess of 1703.11955468 for firm size was too low!
# Exhausted workers: initial guess of 1703.11955468 for firm size is too high!
# Exhausted workers: initial guess of 1703.11955468 for firm size is too high!
# Exhausted workers: initial guess of 1703.11955468 for firm size is too high!
# Exhausted firms: initial guess of 1703.11955468 for firm size was too low!
# Exhausted firms: initial guess of 1703.11955468 for firm size was too low!
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-27-49cca8cc96ec> in <module>()
#       1 solver.solve(2e3, tol=1e-6, number_knots=5000, integrator='lsoda',
# ----> 2              with_jacobian=True, atol=1e-12, rtol=1e-9, message=True)
#
# /Users/drpugh/Research/assortative-matching-large-firms/shooting.pyc in solve(self, guess_firm_size_upper, tol, number_knots, integrator, message, **kwargs)
#     321
#     322             guess_firm_size = self._update_initial_guess(firm_size_lower,
# --> 323                                                          firm_size_upper)
#     324
#     325             self._reset_solution(guess_firm_size)
#
# /Users/drpugh/Research/assortative-matching-large-firms/shooting.pyc in _update_initial_guess(self, lower, upper)
#     173         """Use bisection method to arrive at new initial guess."""
#     174         err_mesg = 'Upper and lower bounds are identical: check solver tols!'
# --> 175         assert (upper - lower) / upper > np.finfo('float').eps, err_mesg
#     176         guess = 0.5 * (lower + upper)
#     177         return guess
#
# AssertionError: Upper and lower bounds are identical: check solver tols!

# %%
solver.solution
# Out:
#             firm productivity    firm size        wage      profit
# x
# 0.001000           100.000000  1703.119555    0.100163  208.499342
# 0.021004            99.591185  1326.466505    0.127701  207.032899
# 0.041008            94.937018  1113.806248    0.140202  190.860216
# 0.061011            84.392173   854.788413    0.149928  156.636272
# 0.081015            72.291928   625.711463    0.158475  121.195152
# 0.101019            61.763899   460.553773    0.166406   93.669970
# 0.121023            53.366772   347.836119    0.173966   73.958607
# 0.141027            46.766432   270.319031    0.181277   59.892015
# 0.161030            41.530205   215.590554    0.188410   49.646073
# 0.181034            37.309595   175.802984    0.195412   41.988315
# 0.201038            33.850368   146.073601    0.202314   36.119952
# 0.221042            30.970655   123.312855    0.209137   31.520234
# 0.241046            28.539642   105.513714    0.215899   27.842644
# 0.261049            26.461907    91.335583    0.222614   24.850925
# 0.281053            24.666676    79.858918    0.229291   22.380051
# 0.301057            23.100568    70.437412    0.235940   20.312096
# 0.321061            21.722674    62.606681    0.242567   18.561018
# 0.341065            20.501172    56.026368    0.249177   17.062842
# 0.361068            19.410972    50.442532    0.255777   15.769184
# 0.381072            18.432038    45.662646    0.262371   14.642879
# 0.401076            17.548192    41.538610    0.268961   13.654981
# 0.421080            16.746234    37.955002    0.275551   12.782660
# 0.441084            16.015288    34.820784    0.282144   12.007697
# 0.461087            15.346318    32.063370    0.288742   11.315402
# 0.481091            14.731754    29.624306    0.295348   10.693817
# 0.501095            14.165210    27.456091    0.301963   10.133118
# 0.521099            13.641257    25.519795    0.308589    9.625170
# 0.541103            13.155258    23.783266    0.315228    9.163188
# 0.561106            12.703222    22.219761    0.321881    8.741470
# 0.581110            12.281699    20.806882    0.328548    8.355194
# ...                       ...          ...         ...         ...
# 99.419890            0.026037     0.000456  463.401811    0.258277
# 99.439894            0.025807     0.000455  463.596589    0.258026
# 99.459897            0.025571     0.000455  463.791444    0.257769
# 99.479901            0.025329     0.000454  463.986380    0.257503
# 99.499905            0.025081     0.000453  464.181397    0.257229
# 99.519909            0.024826     0.000453  464.376495    0.256945
# 99.539913            0.024563     0.000452  464.571678    0.256652
# 99.559916            0.024293     0.000451  464.766946    0.256348
# 99.579920            0.024014     0.000451  464.962301    0.256032
# 99.599924            0.023725     0.000450  465.157744    0.255703
# 99.619928            0.023427     0.000449  465.353278    0.255360
# 99.639932            0.023117     0.000448  465.548905    0.255002
# 99.659935            0.022796     0.000447  465.744627    0.254627
# 99.679939            0.022461     0.000446  465.940447    0.254233
# 99.699943            0.022111     0.000446  466.136368    0.253818
# 99.719947            0.021744     0.000445  466.332394    0.253379
# 99.739951            0.021358     0.000444  466.528527    0.252913
# 99.759954            0.020951     0.000442  466.724773    0.252416
# 99.779958            0.020520     0.000441  466.921136    0.251882
# 99.799962            0.020060     0.000440  467.117622    0.251306
# 99.819966            0.019566     0.000439  467.314238    0.250679
# 99.839970            0.019031     0.000438  467.510993    0.249990
# 99.859973            0.018447     0.000436  467.707897    0.249223
# 99.879977            0.017799     0.000434  467.904964    0.248357
# 99.899981            0.017069     0.000432  468.102209    0.247358
# 99.919985            0.016224     0.000430  468.299659    0.246170
# 99.939989            0.015208     0.000427  468.497347    0.244693
# 99.959992            0.013904     0.000424  468.695332    0.242708
# 99.979996            0.011974     0.000418  468.893733    0.239556
# 100.000000           0.001000     0.000361  469.093041    0.206979
#
# [5000 rows x 4 columns]

# %%
solver.solution.plot(loglog=True)

# %%
np.abs(solver.residuals).plot(logy=True, alpha=0.5)

# %% [markdown]
# # Example:
#
# More sophisticated production function that is not multiplicatively separable...

# %%
# define some workers skill
x, mu1, sigma1 = sym.var('x, mu1, sigma1')
skill_cdf = 0.5 + 0.5 * sym.erf((sym.log(x) - mu1) / sym.sqrt(2 * sigma1**2))
skill_params = {'mu1': 0.0, 'sigma1': 1e0}
skill_bounds = [1e-2, 1e2]

workers = inputs.Input(var=x,
                       cdf=skill_cdf,
                       params=skill_params,
                       bounds=skill_bounds,
                       )

# define some firms
y, mu2, sigma2 = sym.var('y, mu2, sigma2')
productivity_cdf = 0.5 + 0.5 * sym.erf((sym.log(y) - mu2) / sym.sqrt(2 * sigma2**2))
productivity_params = {'mu2': 0.0, 'sigma2': 1e0}
productivity_bounds = [1e-2, 1e2]

firms = inputs.Input(var=y,
                     cdf=productivity_cdf,
                     params=productivity_params,
                     bounds=productivity_bounds,
                     )

# define some valid model params
F_params = {'eta': 0.89, 'kappa': 1.0, 'gamma': 0.54, 'rho': 0.24, 'A': 1.0, 'k': 1.0}

# define a valid production function
A, k, kappa, eta, rho, l, gamma, r = sym.var('A, k, kappa, eta, rho, l, gamma, r')
F = r * A * kappa * eta * ((k * x)**rho + (1 - eta) * (y * (l / r))**rho)**(gamma / rho)

model = models.Model('negative',
                     workers=workers,
                     firms=firms,
                     production=F,
                     params=F_params)

# %%
solver = shooting.ShootingSolver(model=model)

# %%
solver.solve(1e6, tol=1e-3, number_knots=5000, integrator='dopri5',
             atol=1e-12, rtol=1e-9, message=True)
# Out:
# Exhausted workers: initial guess of 500000.0 for firm size is too high!
# Exhausted workers: initial guess of 250000.0 for firm size is too high!
# Exhausted workers: initial guess of 125000.0 for firm size is too high!
# Exhausted firms: initial guess of 62500.0 for firm size is too low.
# Exhausted workers: initial guess of 93750.0 for firm size is too high!
# Exhausted firms: initial guess of 78125.0 for firm size is too low.
# Exhausted workers: initial guess of 85937.5 for firm size is too high!
# Exhausted firms: initial guess of 82031.25 for firm size is too low.
# Exhausted workers: initial guess of 83984.375 for firm size is too high!
# Exhausted firms: initial guess of 83007.8125 for firm size is too low.
# Exhausted firms: initial guess of 83496.09375 for firm size is too low.
# Exhausted firms: initial guess of 83740.234375 for firm size is too low.
# Exhausted workers: initial guess of 83862.3046875 for firm size is too high!
# Exhausted workers: initial guess of 83801.2695312 for firm size is too high!
# Exhausted workers: initial guess of 83770.7519531 for firm size is too high!
# Exhausted firms: initial guess of 83755.4931641 for firm size was too low!
# Exhausted firms: initial guess of 83763.1225586 for firm size was too low!
# Exhausted workers: initial guess of 83766.9372559 for firm size is too high!
# Exhausted workers: initial guess of 83765.0299072 for firm size is too high!
# Exhausted firms: initial guess of 83764.0762329 for firm size was too low!
# Exhausted firms: initial guess of 83764.5530701 for firm size was too low!
# Exhausted firms: initial guess of 83764.7914886 for firm size was too low!
# Exhausted firms: initial guess of 83764.9106979 for firm size was too low!
# Exhausted workers: initial guess of 83764.9703026 for firm size is too high!
# Exhausted workers: initial guess of 83764.9405003 for firm size is too high!
# Exhausted firms: initial guess of 83764.9255991 for firm size was too low!
# Exhausted firms: initial guess of 83764.9330497 for firm size was too low!
# Exhausted firms: initial guess of 83764.936775 for firm size was too low!
# Exhausted firms: initial guess of 83764.9386376 for firm size was too low!
# Exhausted firms: initial guess of 83764.9395689 for firm size was too low!
# Exhausted workers: initial guess of 83764.9400346 for firm size is too high!
# Exhausted firms: initial guess of 83764.9398018 for firm size was too low!
# Exhausted workers: initial guess of 83764.9399182 for firm size is too high!
# Exhausted workers: initial guess of 83764.93986 for firm size is too high!
# Exhausted workers: initial guess of 83764.9398309 for firm size is too high!
# Exhausted firms: initial guess of 83764.9398163 for firm size was too low!
# Exhausted firms: initial guess of 83764.9398236 for firm size was too low!
# Exhausted workers: initial guess of 83764.9398272 for firm size is too high!
# Exhausted workers: initial guess of 83764.9398254 for firm size is too high!
# Exhausted workers: initial guess of 83764.9398245 for firm size is too high!
# Success! All workers and firms are matched

# %%
solver.solution
# Out:
#            firm productivity     firm size           wage     profit
# x
# 0.010000          100.000000  8.376494e+04       0.000237  19.326771
# 0.030002           99.970172  7.386098e+04       0.000258  19.321035
# 0.050004           99.807695  6.860303e+04       0.000270  19.290554
# 0.070006           99.428551  6.478157e+04       0.000280  19.220773
# 0.090008           98.802805  6.163299e+04       0.000289  19.107376
# 0.110010           97.941115  5.886610e+04       0.000296  18.953254
# 0.130012           96.877773  5.635129e+04       0.000302  18.765229
# 0.150014           95.657334  5.402687e+04       0.000308  18.551615
# 0.170016           94.325533  5.186192e+04       0.000314  18.320649
# 0.190018           92.923965  4.983945e+04       0.000319  18.079622
# 0.210020           91.487623  4.794858e+04       0.000324  17.834521
# 0.230022           90.044284  4.618083e+04       0.000329  17.589989
# 0.250024           88.614975  4.452854e+04       0.000334  17.349448
# 0.270026           87.214916  4.298429e+04       0.000338  17.115299
