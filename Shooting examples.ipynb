# %%
# %load_ext autoreload

# %%
autoreload 2

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy as sym

import inputs
import models
import shooting

# %% [markdown]
# # Example:
#
# ## Worker skill and firm productivity are $\sim U[a, b]$...

# %%
# define some workers skill
x, a, b = sym.var('x, a, b')
skill_cdf = (x - a) / (b - a)
skill_params = {'a': 1.0, 'b': 2.0}
skill_bounds = [skill_params['a'], skill_params['b']]

workers = inputs.Input(var=x,
                       cdf=skill_cdf,
                       params=skill_params,
                       bounds=skill_bounds,
                       )

# define some firms
y = sym.var('y')
productivity_cdf = (y - a) / (b - a)
productivity_params = skill_params
productivity_bounds = skill_bounds

firms = inputs.Input(var=y,
                     cdf=productivity_cdf,
                     params=productivity_params,
                     bounds=productivity_bounds,
                     )

# %% [markdown]
# ## ...and production function is multiplicatively separable.
# A particularly attractive case arises under multiplicative separability of the form
#
# $$F(x, y, l, r) = A(x, y)B(l, r)$$
#
# In this case the condition for positive assortative matching can be written as
#
# $$\frac{AA_{xy}}{A_xA_y}\frac{BB_{lr}}{B_lB_r} \ge 1$$
#
# If $B$ has constant elasticity of substitution form, then we obtain an even simpler condition
#
# $$\frac{AA_{xy}}{A_xA_y} \frac{1}{\sigma_{lr}}\ge 1$$
#
# where $\sigma_{lr}$ is the elasticity of substitution between $l$ and $r$.
#
# Finally, if $A$ also has constant elasticity of substitution form, then we obtain an even simpler condition
#
# $$\frac{1}{\sigma_{xy}\sigma_{lr}}\ge 1 \iff \sigma_{xy}\sigma_{lr} \le 1$$
#
# where $\sigma_{xy}$ is the elasticity of substitution between $x$ and $y$.

# %%
# define symbolic expression for CES between x and y
omega_A, sigma_A = sym.var('omega_A, sigma_A')
A = ((omega_A * x**((sigma_A - 1) / sigma_A) + 
     (1 - omega_A) * y**((sigma_A - 1) / sigma_A))**(sigma_A / (sigma_A - 1))) 

# define symbolic expression for Cobb-Douglas between l and r
l, r, omega_B, sigma_B = sym.var('l, r, omega_B, sigma_B')
B = l**omega_B * r**(1 - omega_B)

F = A * B

# %% [markdown]
# Create an instance of the `models.Model` class and an instance of the `solvers.ShootingSolver` class...

# %% [markdown]
# ### Positive assortative matching

# %%
F_params = {'omega_A':0.25, 'omega_B':0.75, 'sigma_A':0.95, 'sigma_B':1.0}

model = models.Model(assortativity='positive',
                     workers=workers,
                     firms=firms,
                     production=F,
                     params=F_params)

solver = shooting.ShootingSolver(model=model)

# %%
solver.solve(1e1, tol=1e-6, number_knots=100, atol=1e-15, rtol=1e-12)
# Out:
# Success! All workers and firms are matched

# %%
# examine the solution attribute
solver.solution
# Out:
#           $\mu(x)$  $\theta(x)$    $w(x)$  $\pi(x)$
# x
# 1.000000  1.000000     0.304740  1.009436  0.102539
# 1.010101  1.031666     0.333492  1.012825  0.112590
# 1.020202  1.060752     0.361288  1.016194  0.122380
# 1.030303  1.087712     0.388244  1.019543  0.131944
# 1.040404  1.112885     0.414452  1.022872  0.141310
# 1.050505  1.136532     0.439987  1.026181  0.150502
# 1.060606  1.158861     0.464912  1.029470  0.159538
# 1.070707  1.180035     0.489278  1.032740  0.168432
# 1.996997    5.562501e-12       3.683520e-12
# 1.997998    3.110312e-11       2.112744e-11
# 1.998999    6.666716e-11       4.542438e-11
# 2.000000    1.142570e-10       7.794185e-11
#
# [1000 rows x 2 columns]

# %% [markdown]
# Here are what the absolute residuals look like...

# %%
solver.residuals.plot(logy=True, alpha=0.5)

# %% [markdown]
# ### Negative assortative matching

# %%
# negative assortativity requires that sigma_A * sigma_B > 1
F_params = {'omega_A':0.25, 'omega_B':0.75, 'sigma_A':1.5, 'sigma_B':1.0}

# %%
model = models.Model(assortativity='negative',
                     workers=workers,
                     firms=firms,
                     production=F,
                     params=F_params)

solver = shooting.ShootingSolver(model=model)

# %%
solver.solve(1e1, tol=1e-6, number_knots=100, atol=1e-15, rtol=1e-12)
# Out:
# Success! All workers and firms are matched

# %%
solver.solution
# Out:
#           $\mu(x)$  $\theta(x)$    $w(x)$  $\pi(x)$
# x
# 1.000000  2.000000     2.421887  1.025798  0.828122
# 1.010101  1.995810     2.399133  1.028683  0.822649
# 1.020202  1.991579     2.376467  1.031556  0.817153
# 1.030303  1.987308     2.353889  1.034417  0.811635
# 1.040404  1.982997     2.331395  1.037268  0.806094
# 1.050505  1.978643     2.308983  1.040108  0.800530
# 1.060606  1.974247     2.286651  1.042937  0.794944
# 1.070707  1.969808     2.264396  1.045755  0.789334
# 1.080808  1.965325     2.242217  1.048563  0.783702
# 1.090909  1.960798     2.220112  1.051361  0.778046
# 1.101010  1.956225     2.198077  1.054149  0.772367
# 1.111111  1.951607     2.176112  1.056927  0.766664
# 1.121212  1.946942     2.154214  1.059695  0.760937
# 1.131313  1.942229     2.132381  1.062454  0.755186
# 1.141414  1.937467     2.110612  1.065204  0.749410
# 1.151515  1.932657     2.088903  1.067944  0.743611
# 1.161616  1.927796     2.067255  1.070676  0.737786
# 1.171717  1.922884     2.045663  1.073399  0.731937
# 1.181818  1.917920     2.024127  1.076113  0.726063
# 1.191919  1.912903     2.002645  1.078818  0.720164
# 1.202020  1.907832     1.981215  1.081516  0.714238
# 1.212121  1.902706     1.959835  1.084205  0.708288
# 1.222222  1.897524     1.938503  1.086886  0.702311
# 1.232323  1.892284     1.917218  1.089559  0.696307
# 1.242424  1.886986     1.895978  1.092224  0.690278
# 1.252525  1.881629     1.874780  1.094882  0.684221
# 1.262626  1.876210     1.853624  1.097533  0.678137
# 1.272727  1.870730     1.832507  1.100176  0.672026
# 1.282828  1.865185     1.811427  1.102811  0.665888
# 1.292929  1.859577     1.790384  1.105440  0.659721
# ...            ...          ...       ...       ...
# 1.707071  1.545353     0.935258  1.208641  0.376797
# 1.717172  1.534427     0.913888  1.211084  0.368932
# 1.727273  1.523243     0.892447  1.213525  0.361002
# 1.737374  1.511786     0.870930  1.215965  0.353007
# 1.747475  1.500042     0.849332  1.218404  0.344943
# 1.757576  1.487995     0.827646  1.220842  0.336808
# 1.767677  1.475627     0.805868  1.223279  0.328600
# 1.777778  1.462919     0.783989  1.225715  0.320316
# 1.787879  1.449851     0.762004  1.228152  0.311952
# 1.797980  1.436400     0.739905  1.230588  0.303506
# 1.808081  1.422539     0.717683  1.233024  0.294973
# 1.818182  1.408241     0.695330  1.235461  0.286351
# 1.828283  1.393474     0.672835  1.237899  0.277634
# 1.838384  1.378203     0.650189  1.240337  0.268818
# 1.848485  1.362389     0.627380  1.242777  0.259898
# 1.858586  1.345987     0.604395  1.245219  0.250868
# 1.868687  1.328946     0.581220  1.247663  0.241722
# 1.878788  1.311208     0.557839  1.250109  0.232453
# 1.888889  1.292707     0.534234  1.252558  0.223053
# 1.898990  1.273365     0.510386  1.255011  0.213513
# 1.909091  1.253093     0.486271  1.257468  0.203824
# 1.919192  1.231782     0.461865  1.259930  0.193972
# 1.929293  1.209306     0.437136  1.262397  0.183946
# 1.939394  1.185511     0.412050  1.264871  0.173730
# 1.949495  1.160208     0.386566  1.267352  0.163305
# 1.959596  1.133164     0.360634  1.269841  0.152649
# 1.969697  1.104078     0.334194  1.272340  0.141736
# 1.979798  1.072566     0.307171  1.274851  0.130532
# 1.989899  1.038111     0.279470  1.277375  0.118996
# 2.000000  1.000000     0.250968  1.279915  0.107073
#
# [100 rows x 4 columns]

# %% [markdown]
# Now we can do all the cool things that one can do with Pandas...

# %%
solver.solution.plot()

# %%
solver.residuals.plot(logy=True, alpha=0.5)

# %% [markdown]
# # Example:
#
# Multiplicative separability with log-normal worker skill and firm productivity distributions...

# %%
# define some workers skill
mu1, sigma1 = sym.var('mu1, sigma1')
skill_cdf = 0.5 + 0.5 * sym.erf((sym.log(x) - mu1) / sym.sqrt(2 * sigma1**2))
skill_params = {'mu1': 0.0, 'sigma1': 1.0}
skill_bounds = [1e-2, 1e2]

workers = inputs.Input(var=x,
                       cdf=skill_cdf,
                       params=skill_params,
                       bounds=skill_bounds,
                       )

# define some firms
mu2, sigma2 = sym.var('mu2, sigma2')
productivity_cdf = 0.5 + 0.5 * sym.erf((sym.log(y) - mu2) / sym.sqrt(2 * sigma2**2))
productivity_params = {'mu2': 0.0, 'sigma2': 1.0}
productivity_bounds = [1e-2, 1e2]

firms = inputs.Input(var=y,
                     cdf=productivity_cdf,
                     params=productivity_params,
                     bounds=productivity_bounds,
                     )

# %% [markdown]
# ### Positive assortative matching

# %%
# define symbolic expression for CES between x and y
omega_A, sigma_A = sym.var('omega_A, sigma_A')
A = ((omega_A * x**((sigma_A - 1) / sigma_A) + 
     (1 - omega_A) * y**((sigma_A - 1) / sigma_A))**(sigma_A / (sigma_A - 1))) 

# define symbolic expression for Cobb-Douglas between l and r
l, r, omega_B, sigma_B = sym.var('l, r, omega_B, sigma_B')
B = l**omega_B * r**(1 - omega_B)

F = A * B

F_params = {'omega_A':0.75, 'omega_B':0.25, 'sigma_A':0.05, 'sigma_B':1.0}

model = models.Model('positive',
                     workers=workers,
                     firms=firms,
                     production=F,
                     params=F_params)

solver = shooting.ShootingSolver(model=model)

# %%
solver.solve(1e0, tol=1e-2, number_knots=10000, integrator='lsoda',
             with_jacobian=True, atol=1e-12, rtol=1e-9, message=True)
# Out:
# Exhausted workers: initial guess of 0.5 for firm size is too high!
# Exhausted firms: initial guess of 0.25 for firm size is too low.
# Exhausted firms: initial guess of 0.375 for firm size is too low.
# Exhausted firms: initial guess of 0.4375 for firm size is too low.
# Exhausted firms: initial guess of 0.46875 for firm size is too low.
# Exhausted workers: initial guess of 0.484375 for firm size is too high!
# Exhausted workers: initial guess of 0.4765625 for firm size is too high!
# Exhausted firms: initial guess of 0.47265625 for firm size is too low.
# Exhausted firms: initial guess of 0.474609375 for firm size is too low.
# Exhausted firms: initial guess of 0.4755859375 for firm size is too low.
# Exhausted workers: initial guess of 0.47607421875 for firm size is too high!
# Exhausted firms: initial guess of 0.475830078125 for firm size is too low.
# Exhausted workers: initial guess of 0.475952148438 for firm size is too high!
# Exhausted workers: initial guess of 0.475891113281 for firm size is too high!
# Exhausted workers: initial guess of 0.475860595703 for firm size is too high!
# Exhausted workers: initial guess of 0.475845336914 for firm size is too high!
# Exhausted workers: initial guess of 0.47583770752 for firm size is too high!
# Exhausted workers: initial guess of 0.475833892822 for firm size is too high!
# Exhausted workers: initial guess of 0.475831985474 for firm size is too high!
# Exhausted workers: initial guess of 0.475831031799 for firm size is too high!
# Exhausted firms: initial guess of 0.475830554962 for firm size is too low.
# Exhausted workers: initial guess of 0.475830793381 for firm size is too high!
# Exhausted firms: initial guess of 0.475830674171 for firm size is too low.
# Exhausted firms: initial guess of 0.475830733776 for firm size is too low.
# Exhausted firms: initial guess of 0.475830763578 for firm size is too low.
# Exhausted workers: initial guess of 0.47583077848 for firm size is too high!
# Exhausted workers: initial guess of 0.475830771029 for firm size is too high!
# Exhausted firms: initial guess of 0.475830767304 for firm size is too low.
# Exhausted workers: initial guess of 0.475830769166 for firm size is too high!
# Exhausted workers: initial guess of 0.475830768235 for firm size is too high!
# Exhausted workers: initial guess of 0.475830767769 for firm size is too high!
# Exhausted workers: initial guess of 0.475830767537 for firm size is too high!
# Exhausted firms: initial guess of 0.47583076742 for firm size is too low.
# Exhausted firms: initial guess of 0.475830767478 for firm size is too low.
# Exhausted firms: initial guess of 0.475830767507 for firm size is too low.
# Exhausted workers: initial guess of 0.475830767522 for firm size is too high!
# Exhausted workers: initial guess of 0.475830767515 for firm size is too high!
# Exhausted firms: initial guess of 0.475830767511 for firm size is too low.
# Exhausted workers: initial guess of 0.475830767513 for firm size is too high!
# Exhausted workers: initial guess of 0.475830767512 for firm size is too high!
# Exhausted workers: initial guess of 0.475830767512 for firm size is too high!
# Exhausted workers: initial guess of 0.475830767511 for firm size is too high!
# Exhausted firms: initial guess of 0.475830767511 for firm size is too low.
# Exhausted firms: initial guess of 0.475830767511 for firm size is too low.
# Exhausted firms: initial guess of 0.475830767511 for firm size is too low.
# Exhausted workers: initial guess of 0.475830767511 for firm size is too high!
# Exhausted workers: initial guess of 0.475830767511 for firm size is too high!
# Exhausted workers: initial guess of 0.475830767511 for firm size is too high!
# Exhausted firms: initial guess of 0.475830767511 for firm size is too low.
# Exhausted firms: initial guess of 0.475830767511 for firm size is too low.
# Exhausted firms: initial guess of 0.475830767511 for firm size is too low.
# Exhausted firms: initial guess of 0.475830767511 for firm size is too low.
# Exhausted firms: initial guess of 0.475830767511 for firm size is too low.
# Exhausted workers: initial guess of 0.475830767511 for firm size is too high!
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-35-82d22a30cd66> in <module>()
#       1 solver.solve(1e0, tol=1e-2, number_knots=10000, integrator='lsoda',
# ----> 2              with_jacobian=True, atol=1e-12, rtol=1e-9, message=True)
#
# /Users/drpugh/Research/assortative-matching-large-firms/shooting.py in solve(self, guess_firm_size_upper, tol, number_knots, integrator, message, **kwargs)
#     350
#     351             guess_firm_size = self._update_initial_guess(firm_size_lower,
# --> 352                                                          firm_size_upper)
#     353
#     354             self._reset_solution(guess_firm_size)
#
# /Users/drpugh/Research/assortative-matching-large-firms/shooting.py in _update_initial_guess(self, lower, upper)
#     202         """Use bisection method to arrive at new initial guess."""
#     203         err_mesg = 'Upper and lower bounds are identical: check solver tols!'
# --> 204         assert (upper - lower) / upper > np.finfo('float').eps, err_mesg
#     205         guess = 0.5 * (lower + upper)
#     206         return guess
#
# AssertionError: Upper and lower bounds are identical: check solver tols!

# %%
solver.solution
# Out:
#               $\mu(x)$  $\theta(x)$     $w(x)$   $\pi(x)$
# x
# 0.010000      0.049637  1690.660083   0.000010   0.048826
# 0.030002      0.049697    20.866881   0.000780   0.048826
# 0.050004      0.052109     2.818415   0.005791   0.048967
# 0.070006      0.064119     1.477636   0.012566   0.055704
# 0.090008      0.080982     1.334629   0.017229   0.068983
# 0.110010      0.098667     1.288824   0.021568   0.083390
# 0.130012      0.116516     1.261339   0.025890   0.097967
# 0.150014      0.134409     1.240395   0.030245   0.112548
# 0.170016      0.152317     1.222976   0.034641   0.127095
# 0.190018      0.170231     1.207911   0.039077   0.141605
# 0.210020      0.188146     1.194596   0.043550   0.156075
# 0.230022      0.206063     1.182656   0.048058   0.170510
# 0.250024      0.223981     1.171833   0.052599   0.184911
# 0.270026      0.241899     1.161941   0.057169   0.199280
# 0.290028      0.259817     1.152835   0.061767   0.213621
# 0.310030      0.277735     1.144403   0.066391   0.227935
# 0.330032      0.295653     1.136556   0.071040   0.242223
# 0.350034      0.313572     1.129221   0.075712   0.256488
# 0.370036      0.331490     1.122338   0.080407   0.270730
# 0.390038      0.349408     1.115857   0.085122   0.284951
# 0.410040      0.367327     1.109734   0.089857   0.299153
# 0.430042      0.385245     1.103935   0.094611   0.313335
# 0.450044      0.403164     1.098427   0.099384   0.327499
# 0.470046      0.421082     1.093185   0.104174   0.341645
# 0.490048      0.439000     1.088185   0.108981   0.355775
# 0.510050      0.456919     1.083407   0.113805   0.369890
# 0.530052      0.474837     1.078832   0.118643   0.383989
# 0.550054      0.492756     1.074445   0.123497   0.398073
# 0.570056      0.510674     1.070231   0.128366   0.412144
# 0.590058      0.528592     1.066179   0.133249   0.426200
# ...                ...          ...        ...        ...
# 99.419942    98.809768     0.482066  42.892921  62.031604
# 99.439944    98.849887     0.481854  42.918049  62.040743
# 99.459946    98.890069     0.481643  42.943213  62.049868
# 99.479948    98.930316     0.481431  42.968413  62.058979
# 0.061996          0.058376          10.719465      0.010029        0.052011
# 0.063996          0.059717           8.643680      0.010701        0.052810
# 0.065996          0.061124           6.235315      0.011350        0.053692
# 0.067995          0.062591           3.769361      0.011971        0.054656
# ...                    ...                ...           ...             ...
# 99.942005        99.878416           0.476464     43.560809       62.265499
# 99.944004        99.882599           0.476442     43.563416       62.266376
# 99.946004        99.886782           0.476421     43.566024       62.267253
# 99.948004        99.890966           0.476399     43.568632       62.268130
# 99.950004        99.895151           0.476377     43.571240       62.269006
# 99.952004        99.899336           0.476355     43.573849       62.269882
# 99.954004        99.903523           0.476333     43.576458       62.270759
# 99.956004        99.907710           0.476312     43.579067       62.271635
# 99.958003        99.911897           0.476290     43.581677       62.272511
# 99.960003        99.916085           0.476268     43.584287       62.273386
# 99.962003        99.920274           0.476246     43.586898       62.274262
# 99.964003        99.924464           0.476224     43.589509       62.275137
# 99.966003        99.928655           0.476202     43.592120       62.276013
# 99.968003        99.932846           0.476181     43.594732       62.276888
# 99.970002        99.937038           0.476159     43.597344       62.277763
# 99.972002        99.941230           0.476137     43.599957       62.278638
# 99.974002        99.945423           0.476115     43.602569       62.279512
# 99.976002        99.949617           0.476093     43.605183       62.280387
# 99.978002        99.953812           0.476071     43.607796       62.281261
# 99.980002        99.958007           0.476049     43.610410       62.282135
# 99.982001        99.962203           0.476028     43.613025       62.283010
# 99.984001        99.966400           0.476006     43.615640       62.283883
# 99.986001        99.970598           0.475984     43.618255       62.284757
# 99.988001        99.974796           0.475962     43.620870       62.285631
# 99.990001        99.978995           0.475940     43.623486       62.286504
# 99.992001        99.983194           0.475918     43.626102       62.287378
# 99.994000        99.987395           0.475896     43.628719       62.288251
# 99.996000        99.991596           0.475875     43.631336       62.289124
# 99.998000        99.995798           0.475853     43.633953       62.289997
# 100.000000      100.000000           0.475831     43.636571       62.290870
#
# [50000 rows x 4 columns]

# %%
solver.interpolated_solution.plot(loglog=True)

# %%
solver.residuals.plot(loglog=True, alpha=0.5)

# %% [markdown]
# ### Negative assortative matching

# %%
# define some workers skill
mu1, sigma1 = sym.var('mu1, sigma1')
skill_cdf = 0.5 + 0.5 * sym.erf((sym.log(x) - mu1) / sym.sqrt(2 * sigma1**2))
skill_params = {'mu1': 0.0, 'sigma1': 1.0}
skill_bounds = [1e-3, 1e3]

workers = inputs.Input(var=x,
                       cdf=skill_cdf,
                       params=skill_params,
                       bounds=skill_bounds,
                       )

# define some firms
mu2, sigma2 = sym.var('mu2, sigma2')
productivity_cdf = 0.5 + 0.5 * sym.erf((sym.log(y) - mu2) / sym.sqrt(2 * sigma2**2))
productivity_params = {'mu2': 0.0, 'sigma2': 1.0}
productivity_bounds = [1e-3, 1e3]

omega_A, sigma_A = sym.var('omega_A, sigma_A')
A = ((omega_A * x**((sigma_A - 1) / sigma_A) + 
     (1 - omega_A) * y**((sigma_A - 1) / sigma_A))**(sigma_A / (sigma_A - 1))) 

# define symbolic expression for Cobb-Douglas between l and r
l, r, omega_B, sigma_B = sym.var('l, r, omega_B, sigma_B')
B = l**omega_B * r**(1 - omega_B)

F = A * B

firms = inputs.Input(var=y,
                     cdf=productivity_cdf,
                     params=productivity_params,
                     bounds=productivity_bounds,
                     )
F_params = {'omega_A':0.25, 'omega_B':0.75, 'sigma_A':1.5, 'sigma_B':1.0}

model = models.Model('negative',
                     workers=workers,
                     firms=firms,
                     production=F,
                     params=F_params)

solver = shooting.ShootingSolver(model=model)

# %%
solver.solve(1e9, tol=1e-3, number_knots=10000, integrator='dop853',
             atol=1e-12, rtol=1e-9, message=True)
# Out:
# Exhausted workers: initial guess of 500000000.0 for firm size is too high!
# Exhausted workers: initial guess of 250000000.0 for firm size is too high!

# %%
solver.solution
# Out:
#           firm productivity     firm size      wage        profit
# x
# 0.001000        1000.000000  1.220703e+08  3.040383  1.237135e+08
# 0.101010         348.057094  1.813997e+06  3.203886  1.937280e+06
# 0.201020         156.824015  7.964676e+04  3.286307  8.724790e+04
# 0.301030          93.485533  1.070454e+04  3.358928  1.198526e+04
# 0.401040          62.358554  2.261469e+03  3.426909  2.583282e+03
# 0.501050          43.873790  5.949377e+02  3.492500  6.926067e+02
# 0.601059          31.549225  1.725873e+02  3.557111  2.046374e+02
# 0.701069          22.608750  5.027735e+01  3.621914  6.070008e+01
# 0.801079          15.615638  1.307599e+01  3.688232  1.607576e+01
# 0.901089           9.592070  2.312030e+00  3.758238  2.896386e+00
# 1.001099           2.073143  1.383323e-02  3.839895  1.770605e-02
# 1.005032           0.006514  1.820565e-08  3.844460  2.333030e-08

# %%
solver.solution.plot(loglog=True)

# %%
solver.residuals
# Out:
#              firm productivity     firm size
# x
# 0.001000         -21360.843509 -1.166961e+05
# 0.011000         214057.758160  3.088759e+07
# 0.021000         401017.639649  5.436097e+07
# 0.031000         253834.218544  3.293469e+07
# 0.041000         105415.023097  1.306172e+07
# 0.051000          33420.559949  3.962162e+06
# 0.061001           7235.487420  8.515208e+05
# 0.071001           -582.343742 -1.500115e+04
# 0.081001          -2282.917310 -1.906684e+05
# 0.091001          -2167.530698 -1.825196e+05
# 0.101001          -1377.194759 -1.356549e+05
# 0.111001          -1528.692672           NaN
# 0.121001           -902.538148           NaN
# 0.131001           -504.495586           NaN
# 0.141001           -222.017062           NaN
# 0.151001            -30.112645           NaN
# 0.161001             87.439341           NaN
# 0.171002            142.915230           NaN
# 0.181002            140.699615           NaN
# 0.191002              8.851732           NaN
# 0.201002            284.585456  2.722496e+04
# 0.211002            139.882543  2.117810e+04
# 0.221002             60.188497  1.452769e+04
# 0.231002             -9.114354  7.869441e+03
# 0.241002            -69.840184  1.705493e+03
# 0.251002           -119.557593 -3.560794e+03
# 0.261002           -155.690539 -7.634711e+03
# 0.271002           -176.322869 -1.034026e+04
# 0.281003           -180.110417 -1.162676e+04
# 0.291003           -164.598168 -1.157104e+04
# ...                        ...           ...
# 999.709997           -0.000107 -5.251048e-09
# 999.719997           -0.000107 -5.270074e-09
# 999.729998           -0.000093 -4.680108e-09
# 999.739998           -0.000067 -3.448820e-09
# 999.749998           -0.000028 -1.600698e-09
# 999.759998            0.000021  7.840911e-10
# 999.769998            0.000078  3.571220e-09
# 999.779998            0.000139  6.574180e-09
# 999.789998            0.000199  9.556799e-09
# 999.799998            0.000251  1.223641e-08
# 999.809998            0.000290  1.428778e-08
# 999.819998            0.000308  1.534815e-08
# 999.829998            0.000296  1.502359e-08
# 999.839999            0.000247  1.289776e-08
# 999.849999            0.000153  8.544066e-09
# 999.859999            0.000006  1.543752e-09
# 999.869999           -0.000201 -8.486052e-09
# 999.879999           -0.000471 -2.184704e-08
# 999.889999           -0.000806 -3.868363e-08
# 999.899999           -0.001199 -5.884973e-08
# 999.909999           -0.001630 -8.166544e-08
# 999.919999           -0.002056 -1.054491e-07
# 999.929999           -0.002392 -1.265619e-07
# 999.939999           -0.002463 -1.373110e-07
# 999.950000           -0.001906 -1.209235e-07
# 999.960000            0.000097 -3.809962e-08
# 999.970000            0.005592  2.143550e-07
# 999.980000            0.020557  9.566089e-07
# 999.990000            0.066930  3.457784e-06
# 1000.000000           0.259280  1.507616e-05
#
# [100000 rows x 2 columns]

# %%
np.abs(solver.residuals).plot(logy=True, alpha=0.5)

# %% [markdown]
# # Example:
#
# More sophisticated production function that is not multiplicatively separable...

# %%
# define some workers skill
x, mu1, sigma1 = sym.var('x, mu1, sigma1')
skill_cdf = 0.5 + 0.5 * sym.erf((sym.log(x) - mu1) / sym.sqrt(2 * sigma1**2))
skill_params = {'mu1': 0.0, 'sigma1': 1e0}
skill_bounds = [1e-2, 1e2]

workers = inputs.Input(var=x,
                       cdf=skill_cdf,
                       params=skill_params,
                       bounds=skill_bounds,
                       )

# define some firms
y, mu2, sigma2 = sym.var('y, mu2, sigma2')
productivity_cdf = 0.5 + 0.5 * sym.erf((sym.log(y) - mu2) / sym.sqrt(2 * sigma2**2))
productivity_params = {'mu2': 0.0, 'sigma2': 1e0}
productivity_bounds = [1e-2, 1e2]

firms = inputs.Input(var=y,
                     cdf=productivity_cdf,
                     params=productivity_params,
                     bounds=productivity_bounds,
                     )

# define some valid model params
F_params = {'eta': 0.89, 'kappa': 1.0, 'gamma': 0.54, 'rho': 0.24, 'A': 1.0, 'k': 1.0}

# define a valid production function
A, k, kappa, eta, rho, l, gamma, r = sym.var('A, k, kappa, eta, rho, l, gamma, r')
F = r * A * kappa * eta * ((k * x)**rho + (1 - eta) * (y * (l / r))**rho)**(gamma / rho)

model = models.Model('negative',
                     workers=workers,
                     firms=firms,
                     production=F,
                     params=F_params)

# %%
solver = shooting.ShootingSolver(model=model)

# %%
solver.solve(1e6, tol=1e-3, number_knots=5000, integrator='dopri5',
             atol=1e-12, rtol=1e-9, message=True)
# Out:
# Exhausted workers: initial guess of 500000.0 for firm size is too high!
# Exhausted workers: initial guess of 250000.0 for firm size is too high!
# Exhausted workers: initial guess of 125000.0 for firm size is too high!
# Exhausted firms: initial guess of 62500.0 for firm size is too low.
# Exhausted workers: initial guess of 93750.0 for firm size is too high!
# Exhausted firms: initial guess of 78125.0 for firm size is too low.
# Exhausted workers: initial guess of 85937.5 for firm size is too high!
# Exhausted firms: initial guess of 82031.25 for firm size is too low.
# Exhausted workers: initial guess of 83984.375 for firm size is too high!
# Exhausted firms: initial guess of 83007.8125 for firm size is too low.
# Exhausted firms: initial guess of 83496.09375 for firm size is too low.
# Exhausted firms: initial guess of 83740.234375 for firm size is too low.
# Exhausted workers: initial guess of 83862.3046875 for firm size is too high!
# Exhausted workers: initial guess of 83801.2695312 for firm size is too high!
# Exhausted workers: initial guess of 83770.7519531 for firm size is too high!
# Exhausted firms: initial guess of 83755.4931641 for firm size was too low!
# Exhausted firms: initial guess of 83763.1225586 for firm size was too low!
# Exhausted workers: initial guess of 83766.9372559 for firm size is too high!
# Exhausted workers: initial guess of 83765.0299072 for firm size is too high!
# Exhausted firms: initial guess of 83764.0762329 for firm size was too low!
# Exhausted firms: initial guess of 83764.5530701 for firm size was too low!
# Exhausted firms: initial guess of 83764.7914886 for firm size was too low!
# Exhausted firms: initial guess of 83764.9106979 for firm size was too low!
# Exhausted workers: initial guess of 83764.9703026 for firm size is too high!
# Exhausted workers: initial guess of 83764.9405003 for firm size is too high!
# Exhausted firms: initial guess of 83764.9255991 for firm size was too low!
# Exhausted firms: initial guess of 83764.9330497 for firm size was too low!
# Exhausted firms: initial guess of 83764.936775 for firm size was too low!
# Exhausted firms: initial guess of 83764.9386376 for firm size was too low!
# Exhausted firms: initial guess of 83764.9395689 for firm size was too low!
# Exhausted workers: initial guess of 83764.9400346 for firm size is too high!
# Exhausted firms: initial guess of 83764.9398018 for firm size was too low!
# Exhausted workers: initial guess of 83764.9399182 for firm size is too high!
# Exhausted workers: initial guess of 83764.93986 for firm size is too high!
# Exhausted workers: initial guess of 83764.9398309 for firm size is too high!
# Exhausted firms: initial guess of 83764.9398163 for firm size was too low!
# Exhausted firms: initial guess of 83764.9398236 for firm size was too low!
# Exhausted workers: initial guess of 83764.9398272 for firm size is too high!
# Exhausted workers: initial guess of 83764.9398254 for firm size is too high!
# Exhausted workers: initial guess of 83764.9398245 for firm size is too high!
# Success! All workers and firms are matched

# %%
solver.solution
# Out:
#            firm productivity     firm size           wage     profit
# x
# 0.010000          100.000000  8.376494e+04       0.000237  19.326771
# 0.030002           99.970172  7.386098e+04       0.000258  19.321035
# 0.050004           99.807695  6.860303e+04       0.000270  19.290554
# 0.070006           99.428551  6.478157e+04       0.000280  19.220773
# 0.090008           98.802805  6.163299e+04       0.000289  19.107376
# 0.110010           97.941115  5.886610e+04       0.000296  18.953254
# 0.130012           96.877773  5.635129e+04       0.000302  18.765229
# 0.150014           95.657334  5.402687e+04       0.000308  18.551615
# 0.170016           94.325533  5.186192e+04       0.000314  18.320649
# 0.190018           92.923965  4.983945e+04       0.000319  18.079622
# 0.210020           91.487623  4.794858e+04       0.000324  17.834521
# 0.230022           90.044284  4.618083e+04       0.000329  17.589989
# 0.250024           88.614975  4.452854e+04       0.000334  17.349448
# 0.270026           87.214916  4.298429e+04       0.000338  17.115299
# 0.290028           85.854608  4.154073e+04       0.000343  16.889132
