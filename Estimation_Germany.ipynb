# %%
# %load_ext autoreload

# %%
autoreload 2

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
from scipy import stats, optimize
import numpy as np
import sympy as sym

import inputs
import models
import shooting

from __future__ import division
from sympy import init_printing

# %% [markdown]
# ### Welcome to the Estimation notebook!
#
# This notebook defines some workers and firms - usign parameters obtained from Distributions.ipynb - solves for a first run of the model and then uses the estimation code to get the sum of squared residuals between data (taken from PD05_wage.csv) and the implied functions of the model: mu(x), theta(x), w(x)

# %%
# define some default workers skill
x, mu1, sigma1 = sym.var('x, mu1, sigma1')
skill_cdf = 1e6*(0.5 + 0.5 * sym.erf((sym.log(x) - mu1) / sym.sqrt(2 * sigma1**2)))
skill_params = {'mu1': 0, 'sigma1': 1.0}
skill_bounds = [1e-2, 8.0]

workers = inputs.Input(var=x,
                       cdf=skill_cdf,
                       params=skill_params,
                       bounds=skill_bounds,
                       )

# define some default firms
y, mu2, sigma2 = sym.var('y, mu2, sigma2')
productivity_cdf = 1e4*(0.5 + 0.5 * sym.erf((sym.log(y) - mu2) / sym.sqrt(2 * sigma2**2)))
productivity_params = {'mu2': 0.0, 'sigma2': 1.0}
productivity_bounds = [1e-2, 8.0]

firms = inputs.Input(var=y,
                     cdf=productivity_cdf,
                     params=productivity_params,
                     bounds=productivity_bounds,
                     )

# define symbolic expression for CES between x and y
omega_A, sigma_A, Big_A = sym.var('omega_A, sigma_A, Big_A')
A = ((omega_A * x**((sigma_A - 1) / sigma_A) + 
     (1 - omega_A) * y**((sigma_A - 1) / sigma_A))**(sigma_A / (sigma_A - 1))) 

# define symbolic expression for Cobb-Douglas between l and r
l, r, omega_B, sigma_B = sym.var('l, r, omega_B, sigma_B')
B = l**omega_B * r**(1 - omega_B)

F = Big_A * (A * B)

F_params = {'omega_A':0.6, 'omega_B':0.8, 'sigma_A':0.9, 'Big_A':1e3}

model = models.Model('positive',
                     workers=workers,
                     firms=firms,
                     production=F,
                     params=F_params)

solver = shooting.ShootingSolver(model=model)

# %%
init_printing()
F.diff(x,y)
# Out:
#
#
#
#                           σ_A - 1  σ_A - 1                          ⎛     σ_A
#                           ───────  ───────                          ⎜     ────
#        ω_B      -ω_B + 1    σ_A      σ_A   ⎛     σ_A - 1⎞           ⎜       σ_
# Big_A⋅l   ⋅ω_A⋅r        ⋅x       ⋅y       ⋅⎜-1 + ───────⎟⋅(ω_A - 1)⋅⎝ω_A⋅x
#                                            ⎝       σ_A  ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                                                           2
#                                        ⎛     σ_A - 1    σ_A - 1          ⎞
#                                        ⎜     ───────    ───────          ⎟
#                                        ⎜       σ_A        σ_A            ⎟
#                                    x⋅y⋅⎝ω_A⋅x        - y       ⋅(ω_A - 1)⎠
#
#                            σ_A
#                          ───────
#                          σ_A - 1
# - 1    σ_A - 1          ⎞
# ───    ───────          ⎟
# A        σ_A            ⎟
#     - y       ⋅(ω_A - 1)⎠
#
# ────────────────────────────────

# %%
init_printing()
F.diff(l,r)
# Out:
#                                                                          σ_A
#                                                                        ───────
#                                                                        σ_A - 1
#                                     ⎛     σ_A - 1    σ_A - 1          ⎞
#                                     ⎜     ───────    ───────          ⎟
#         ω_B      -ω_B + 1           ⎜       σ_A        σ_A            ⎟
# -Big_A⋅l   ⋅ω_B⋅r        ⋅(ω_B - 1)⋅⎝ω_A⋅x        - y       ⋅(ω_A - 1)⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                       l⋅r
#
#
#
#
#
#
#
#
# ─

# %%
init_printing()
F.diff(y,l)
# Out:
#
#
#
#                            σ_A - 1           ⎛     σ_A - 1    σ_A - 1
#                            ───────           ⎜     ───────    ───────
#         ω_B      -ω_B + 1    σ_A             ⎜       σ_A        σ_A
# -Big_A⋅l   ⋅ω_B⋅r        ⋅y       ⋅(ω_A - 1)⋅⎝ω_A⋅x        - y       ⋅(ω_A - 1
# ──────────────────────────────────────────────────────────────────────────────
#                             ⎛     σ_A - 1    σ_A - 1          ⎞
#                             ⎜     ───────    ───────          ⎟
#                             ⎜       σ_A        σ_A            ⎟
#                         l⋅y⋅⎝ω_A⋅x        - y       ⋅(ω_A - 1)⎠
#
#     σ_A
#   ───────
#   σ_A - 1
#  ⎞
#  ⎟
#  ⎟
# )⎠
# ──────────

# %%
init_printing()
F.diff(x,r)
# Out:
#
#
#
#                            σ_A - 1           ⎛     σ_A - 1    σ_A - 1
#                            ───────           ⎜     ───────    ───────
#         ω_B      -ω_B + 1    σ_A             ⎜       σ_A        σ_A
# -Big_A⋅l   ⋅ω_A⋅r        ⋅x       ⋅(ω_B - 1)⋅⎝ω_A⋅x        - y       ⋅(ω_A - 1
# ──────────────────────────────────────────────────────────────────────────────
#                             ⎛     σ_A - 1    σ_A - 1          ⎞
#                             ⎜     ───────    ───────          ⎟
#                             ⎜       σ_A        σ_A            ⎟
#                         r⋅x⋅⎝ω_A⋅x        - y       ⋅(ω_A - 1)⎠
#
#     σ_A
#   ───────
#   σ_A - 1
#  ⎞
#  ⎟
#  ⎟
# )⎠
# ──────────

# %%
init_printing()
F.diff(x,y)*F.diff(l,r)
# Out:
#
#
#
#                                     σ_A - 1  σ_A - 1
#                                     ───────  ───────
#       2  2⋅ω_B          -2⋅ω_B + 2    σ_A      σ_A   ⎛     σ_A - 1⎞
# -Big_A ⋅l     ⋅ω_A⋅ω_B⋅r          ⋅x       ⋅y       ⋅⎜-1 + ───────⎟⋅(ω_A - 1)⋅
#                                                      ⎝       σ_A  ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                     ⎛     σ_A - 1    σ_A - 1
#                                                     ⎜     ───────    ───────
#                                                     ⎜       σ_A        σ_A
#                                             l⋅r⋅x⋅y⋅⎝ω_A⋅x        - y       ⋅(
#
#                                               2⋅σ_A
#                                              ───────
#                                              σ_A - 1
#           ⎛     σ_A - 1    σ_A - 1          ⎞
#           ⎜     ───────    ───────          ⎟
#           ⎜       σ_A        σ_A            ⎟
# (ω_B - 1)⋅⎝ω_A⋅x        - y       ⋅(ω_A - 1)⎠
#
# ─────────────────────────────────────────────────────
#          2
#         ⎞
#         ⎟
#         ⎟
# ω_A - 1)⎠

# %%
init_printing()
F.diff(y,l)*F.diff(x,r)
# Out:
#
#
#
#                                    σ_A - 1  σ_A - 1                     ⎛
#                                    ───────  ───────                     ⎜
#      2  2⋅ω_B          -2⋅ω_B + 2    σ_A      σ_A                       ⎜
# Big_A ⋅l     ⋅ω_A⋅ω_B⋅r          ⋅x       ⋅y       ⋅(ω_A - 1)⋅(ω_B - 1)⋅⎝ω_A⋅x
# ──────────────────────────────────────────────────────────────────────────────
#
#                                            ⎛     σ_A - 1    σ_A - 1          ⎞
#                                            ⎜     ───────    ───────          ⎟
#                                            ⎜       σ_A        σ_A            ⎟
#                                    l⋅r⋅x⋅y⋅⎝ω_A⋅x        - y       ⋅(ω_A - 1)⎠
#
#                               2⋅σ_A
#                              ───────
#                              σ_A - 1
# σ_A - 1    σ_A - 1          ⎞
# ───────    ───────          ⎟
#   σ_A        σ_A            ⎟
#         - y       ⋅(ω_A - 1)⎠
# ────────────────────────────────────
# 2

# %%
solver.solve(1000.0, tol=1e-6, number_knots=1000, integrator='lsoda', message=True)
# Out:
# Exhausted workers: initial guess of 500.0 for firm size is too high!
# Exhausted firms: initial guess of 250.0 for firm size is too low.
# Exhausted firms: initial guess of 375.0 for firm size is too low.
# Exhausted workers: initial guess of 437.5 for firm size is too high!
# Exhausted workers: initial guess of 406.25 for firm size is too high!
# Exhausted workers: initial guess of 390.625 for firm size is too high!
# Exhausted workers: initial guess of 382.8125 for firm size is too high!
# Exhausted workers: initial guess of 378.90625 for firm size is too high!
# Exhausted firms: initial guess of 376.953125 for firm size is too low.
# Exhausted firms: initial guess of 377.9296875 for firm size is too low.
# Exhausted workers: initial guess of 378.41796875 for firm size is too high!
# Exhausted firms: initial guess of 378.173828125 for firm size is too low.
# Exhausted firms: initial guess of 378.295898438 for firm size is too low.
# Exhausted workers: initial guess of 378.356933594 for firm size is too high!
# Exhausted firms: initial guess of 378.326416016 for firm size is too low.
# Exhausted firms: initial guess of 378.341674805 for firm size is too low.
# Exhausted firms: initial guess of 378.349304199 for firm size is too low.
# Exhausted workers: initial guess of 378.353118896 for firm size is too high!
# Exhausted workers: initial guess of 378.351211548 for firm size is too high!
# Exhausted firms: initial guess of 378.350257874 for firm size is too low.
# Exhausted firms: initial guess of 378.350734711 for firm size is too low.
# Exhausted firms: initial guess of 378.350973129 for firm size is too low.
# Exhausted workers: initial guess of 378.351092339 for firm size is too high!
# Exhausted firms: initial guess of 378.351032734 for firm size is too low.
# Exhausted workers: initial guess of 378.351062536 for firm size is too high!
# Exhausted firms: initial guess of 378.351047635 for firm size is too low.
# Exhausted workers: initial guess of 378.351055086 for firm size is too high!
# Exhausted workers: initial guess of 378.35105136 for firm size is too high!
# Exhausted workers: initial guess of 378.351049498 for firm size is too high!
# Exhausted workers: initial guess of 378.351048566 for firm size is too high!
# Exhausted firms: initial guess of 378.351048101 for firm size is too low.
# Exhausted workers: initial guess of 378.351048334 for firm size is too high!
# Exhausted firms: initial guess of 378.351048217 for firm size is too low.
# Exhausted workers: initial guess of 378.351048275 for firm size is too high!
# Exhausted firms: initial guess of 378.351048246 for firm size was too low!
# Exhausted firms: initial guess of 378.351048261 for firm size was too low!
# Exhausted workers: initial guess of 378.351048268 for firm size is too high!
# Exhausted workers: initial guess of 378.351048264 for firm size is too high!
# Exhausted firms: initial guess of 378.351048263 for firm size was too low!
# Exhausted workers: initial guess of 378.351048264 for firm size is too high!
# Exhausted workers: initial guess of 378.351048263 for firm size is too high!
# Exhausted workers: initial guess of 378.351048263 for firm size is too high!
# Exhausted workers: initial guess of 378.351048263 for firm size is too high!
# Exhausted firms: initial guess of 378.351048263 for firm size was too low!
# Exhausted firms: initial guess of 378.351048263 for firm size was too low!
# Exhausted firms: initial guess of 378.351048263 for firm size was too low!
# Exhausted firms: initial guess of 378.351048263 for firm size was too low!
# Exhausted workers: initial guess of 378.351048263 for firm size is too high!
# Exhausted workers: initial guess of 378.351048263 for firm size is too high!
# Exhausted firms: initial guess of 378.351048263 for firm size was too low!
# Exhausted firms: initial guess of 378.351048263 for firm size was too low!
# Exhausted workers: initial guess of 378.351048263 for firm size is too high!
# Success! All workers and firms are matched

# %% [markdown]
# ** Now that everything is defined, let's try to solve the model once first! **
#
# This will give us a good idea about inital guesses and number of knots.

# %%
solver.solve(106.0, tol=1e-6, number_knots=1000, integrator='lsoda', atol=1e-15, rtol=1e-12, message=True)
# Out:
# Exhausted workers: initial guess of 53.0 for firm size is too high!
# Exhausted workers: initial guess of 26.5 for firm size is too high!
# Exhausted workers: initial guess of 13.25 for firm size is too high!
# Exhausted workers: initial guess of 6.625 for firm size is too high!
# Exhausted workers: initial guess of 3.3125 for firm size is too high!
# Exhausted firms: initial guess of 1.65625 for firm size is too low.
# Exhausted firms: initial guess of 2.484375 for firm size is too low.
# Exhausted firms: initial guess of 2.8984375 for firm size is too low.
# Exhausted workers: initial guess of 3.10546875 for firm size is too high!
# Exhausted workers: initial guess of 3.001953125 for firm size is too high!
# Exhausted workers: initial guess of 2.9501953125 for firm size is too high!
# Exhausted firms: initial guess of 2.92431640625 for firm size is too low.
# Exhausted workers: initial guess of 2.93725585938 for firm size is too high!
# Exhausted firms: initial guess of 2.93078613281 for firm size is too low.
# Exhausted firms: initial guess of 2.93402099609 for firm size is too low.
# Exhausted workers: initial guess of 2.93563842773 for firm size is too high!
# Exhausted workers: initial guess of 2.93482971191 for firm size is too high!
# Exhausted firms: initial guess of 2.934425354 for firm size is too low.
# Exhausted workers: initial guess of 2.93462753296 for firm size is too high!
# Exhausted firms: initial guess of 2.93452644348 for firm size is too low.
# Exhausted workers: initial guess of 2.93457698822 for firm size is too high!
# Exhausted workers: initial guess of 2.93455171585 for firm size is too high!
# Exhausted firms: initial guess of 2.93453907967 for firm size is too low.
# Exhausted firms: initial guess of 2.93454539776 for firm size is too low.
# Exhausted firms: initial guess of 2.9345485568 for firm size is too low.
# Exhausted firms: initial guess of 2.93455013633 for firm size is too low.
# Exhausted workers: initial guess of 2.93455092609 for firm size is too high!
# Exhausted workers: initial guess of 2.93455053121 for firm size is too high!
# Exhausted workers: initial guess of 2.93455033377 for firm size is too high!
# Exhausted firms: initial guess of 2.93455023505 for firm size is too low.
# Exhausted workers: initial guess of 2.93455028441 for firm size is too high!
# Exhausted firms: initial guess of 2.93455025973 for firm size is too low.
# Exhausted workers: initial guess of 2.93455027207 for firm size is too high!
# Exhausted workers: initial guess of 2.9345502659 for firm size is too high!
# Exhausted workers: initial guess of 2.93455026281 for firm size is too high!
# Exhausted firms: initial guess of 2.93455026127 for firm size is too low.
# Exhausted workers: initial guess of 2.93455026204 for firm size is too high!
# Exhausted firms: initial guess of 2.93455026166 for firm size is too low.
# Exhausted firms: initial guess of 2.93455026185 for firm size was too low!
# Exhausted firms: initial guess of 2.93455026195 for firm size was too low!
# Exhausted workers: initial guess of 2.93455026199 for firm size is too high!
# Exhausted firms: initial guess of 2.93455026197 for firm size was too low!
# Exhausted workers: initial guess of 2.93455026198 for firm size is too high!
# Exhausted workers: initial guess of 2.93455026198 for firm size is too high!
# Exhausted workers: initial guess of 2.93455026197 for firm size is too high!
# Exhausted firms: initial guess of 2.93455026197 for firm size was too low!
# Exhausted firms: initial guess of 2.93455026197 for firm size was too low!
# Exhausted firms: initial guess of 2.93455026197 for firm size was too low!
# Exhausted workers: initial guess of 2.93455026197 for firm size is too high!
# Exhausted firms: initial guess of 2.93455026197 for firm size was too low!
# Exhausted workers: initial guess of 2.93455026197 for firm size is too high!
# Exhausted firms: initial guess of 2.93455026197 for firm size was too low!
# Exhausted workers: initial guess of 2.93455026197 for firm size is too high!
# Exhausted workers: initial guess of 2.93455026197 for firm size is too high!
# Success! All workers and firms are matched

# %%
# Plotting the residuals
solver.residuals.plot(loglog=True, alpha=0.5)
plt.show()

# %%
solver.solution
# Out:
#           $\mu(x)$  $\theta(x)$       $w(x)$       $\pi(x)$
# x
# 0.010000  0.010000     0.217317    10.856034       0.589800
# 0.017998  0.048986     2.870900    17.174727      12.326733
# 0.025996  0.070876     4.291741    22.904845      24.575417
#          3.79098741e+02,   3.79016236e+02,   3.78933584e+02,
#          3.78850785e+02,   3.78767839e+02,   3.78684746e+02,
#          3.78601506e+02,   3.78518120e+02,   3.78434589e+02,
#          3.78351048e+02])

# %% [markdown]
# ** Time to import the estimation_code **

# %%
#Getting firm size distribution differently
thetas_hat = solver.solution['$\\theta(x)$'].values
ys_hat = solver.solution['$\\mu(x)$'].values
rxs = solver.solution.index.values
#plt.plot(ys_hat,rxs)
def pdf_workers(x):
    return 1e6*(0.5*np.sqrt(2)*np.exp(-(-0.0 + x)**2/(2*1.0**2))/(np.sqrt(np.pi)*np.sqrt(1.0**2)))
pdf_x = pdf_workers(rxs)
mysize = []
cdfsize = []
r = 0.0
#need to order by size! Why does y-axis not go up to total number of firms?
for i in range(len(rxs)):
    mysize.append(pdf_x[i]/thetas_hat[i])
    r += mysize[i]
    cdfsize.append(r)
    #print cdfsize[i]
plt.figure(figsize=(15,5))


plt.subplot(131)    
plt.plot(thetas_hat,cdfsize)   

plt.subplot(132)
plt.plot(rxs,thetas_hat)

# %%
import new_estimation_file as est

# %% [markdown]
# Now we can try if the objective function works:

# %%
# Starting arbitrary parameters
ps = (0.9, 0.93, 0.3)

# Reading data from csv file
theta,wage,profit,wgt = est.import_data('forestimation.csv', ID=True, weights=True)

# Worker skill parameters are taken from Histograms.ipynb - and correspond to log wages mean and variance
#skill_p = (1.0000000000000002, 0.16382221849787501)
#skill_b = [1e-2, 1.4991086434]

#skill_p = (3.8894753094349528, 0.63718247398434291)
#skill_b = [0.01, 340.6127]

# Firm skill parameters are also taken from Histograms.ipynb - and correspond to log profit mean and variance (firm level)
#firm_p = (1.0000000000000002, 0.26979838777863219)
#firm_b = [0.0921194652671, 1.95530939088]

#firm_p = (7.13768801209, 1.92573671813)
#firm_b = [1.93, 1151284.0]

# Run!
#est.ObjectiveFunction(ps, (xs, ys, thetas, ws), skill_p, skill_b, firm_p, firm_b, 2.3)

# %% [markdown]
# Or try the two functions individually:

# %%
# SolveModel
functions, new_guess = est.Solve_Model(F, F_params, workers, firms, 'positive', 6000.0, 'lsoda', 2.3)
mu_hat, theta_hat, w_hat = functions
# Out:
# Success! All workers and firms are matched

# %%
# Plotting the function vs the data (some fit better than others)
mus1 = []
ys_copy = np.sort(ys)
for i in range(len(ys_copy)):
    mus1.append(theta_hat(ys_copy[i]))
plt.plot(ys_copy, mus1, c='black')
plt.scatter(ys, thetas, c='r')
#plt.xlim(0,10)
#plt.ylim(0,500)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-17303a37e170> in <module>()
#       1 # Plotting the function vs the data (some fit better than others)
#       2 mus1 = []
# ----> 3 ys_copy = np.sort(ys)
#       4 for i in range(len(ys_copy)):
#       5     mus1.append(theta_hat(ys_copy[i]))
#
# NameError: name 'ys' is not defined

# %%
# Checking the mean square error - actually, the sum of squared errors of mu(x), theta(x), w(x)
est.Calculate_MSE( (xs, ys, thetas, ws), (mu_hat, theta_hat, w_hat) )

# %% [markdown]
# ## Iterate for some parameters

# %% [markdown]
# ## $\omega_b$

# %%
h_theta = 100
results9 = np.zeros(2)
bad_result9 = np.zeros(2)
for om in np.arange(0.9,0.05,-0.05):
    params_i = {'omega_A':0.75, 'omega_B':om, 'sigma_A':0.6, 'sigma_B':1.0}
    try:
        # Solving Phase
        functions, guess = est.Solve_Model(F, params_i, workers, firms, 'positive', 6000, 'lsoda', h_theta)
        mu_hat, theta_hat, w_hat = functions
        err = (est.Calculate_MSE((xs, ys, thetas, ws), (mu_hat, theta_hat, w_hat)))
        # Storage phase
        results_i = np.hstack((om,err))        
        results9 = np.vstack((results9,results_i))
        # Update phase
        h_theta = guess
        print 'Done with', om
    except AssertionError:
        results_i = np.hstack((om,'Failure'))
        bad_result9 = np.vstack((bad_result9,results_i))
        print 'Skipped error', om
        pass
# Out:
# Success! All workers and firms are matched
# Done with 0.9
# Success! All workers and firms are matched
# Done with 0.85
# Success! All workers and firms are matched
# Done with 0.8
# Success! All workers and firms are matched
# Done with 0.75
# Success! All workers and firms are matched
# Done with 0.7
# Success! All workers and firms are matched
# Done with 0.65
# Success! All workers and firms are matched
# Done with 0.6
# Success! All workers and firms are matched
# Done with 0.55
# Success! All workers and firms are matched
# Done with 0.5
# Success! All workers and firms are matched
# Done with 0.45
# Success! All workers and firms are matched
# Done with 0.4
# Skipped error 0.35
# Skipped error 0.3
# Skipped error 0.25
# Skipped error 0.2
# Skipped error 0.15
# Skipped error 0.1

# %%
h_theta = 100
results10 = np.zeros(2)
bad_result10 = np.zeros(2)
for om in np.arange(0.9,0.05,-0.05):
    params_i = {'omega_A':0.25, 'omega_B':om, 'sigma_A':0.6, 'sigma_B':1.0}
    try:
        # Solving Phase
        functions, guess = est.Solve_Model(F, params_i, workers, firms, 'positive', 6000, 'lsoda', h_theta)
        mu_hat, theta_hat, w_hat = functions
        err = (est.Calculate_MSE((xs, ys, thetas, ws), (mu_hat, theta_hat, w_hat)))
        # Storage phase
        results_i = np.hstack((om,err))        
        results10 = np.vstack((results10,results_i))
        # Update phase
        h_theta = guess
        print 'Done with', om
    except AssertionError:
        results_i = np.hstack((om,'Failure'))
        bad_result10 = np.vstack((bad_result10,results_i))
        print 'Skipped error', om
        pass
# Out:
# Skipped error 0.9
# Skipped error 0.85
# Success! All workers and firms are matched
# Done with 0.8
# Success! All workers and firms are matched
# Done with 0.75
# Success! All workers and firms are matched
# Done with 0.7
# Success! All workers and firms are matched
# Done with 0.65
# Success! All workers and firms are matched
# Done with 0.6
# Success! All workers and firms are matched
# Done with 0.55
# Success! All workers and firms are matched
# Done with 0.5
# Success! All workers and firms are matched
# Done with 0.45
# Success! All workers and firms are matched
# Done with 0.4
# Skipped error 0.35
# Skipped error 0.3
# Skipped error 0.25
# Skipped error 0.2
# Skipped error 0.15
# Skipped error 0.1

# %%
h_theta = 100
results11 = np.zeros(2)
bad_result11 = np.zeros(2)
for om in np.arange(0.9,0.05,-0.05):
    params_i = {'omega_A':0.75, 'omega_B':om, 'sigma_A':0.3, 'sigma_B':1.0}
    try:
        # Solving Phase
        functions, guess = est.Solve_Model(F, params_i, workers, firms, 'positive', 6000, 'lsoda', h_theta)
        mu_hat, theta_hat, w_hat = functions
        err = (est.Calculate_MSE((xs, ys, thetas, ws), (mu_hat, theta_hat, w_hat)))
        # Storage phase
        results_i = np.hstack((om,err))        
        results11 = np.vstack((results11,results_i))
        # Update phase
        h_theta = guess
        print 'Done with', om
    except AssertionError:
        results_i = np.hstack((om,'Failure'))
        bad_result11 = np.vstack((bad_result11,results_i))
        print 'Skipped error', om
        pass
# Out:
# Success! All workers and firms are matched
# Done with 0.9
# Success! All workers and firms are matched
# Done with 0.85
# Success! All workers and firms are matched
# Done with 0.8
# Success! All workers and firms are matched
# Done with 0.75
# Success! All workers and firms are matched
# Done with 0.7
# Success! All workers and firms are matched
# Done with 0.65
# Success! All workers and firms are matched
# Done with 0.6
# Success! All workers and firms are matched
# Done with 0.55
# Success! All workers and firms are matched
# Done with 0.5
# Success! All workers and firms are matched
# Done with 0.45
# Success! All workers and firms are matched
# Done with 0.4
# Success! All workers and firms are matched
# Done with 0.35
# Skipped error 0.3
# Skipped error 0.25
# Skipped error 0.2
# Skipped error 0.15
# Skipped error 0.1

# %%
h_theta = 100
results12 = np.zeros(2)
bad_result12 = np.zeros(2)
for om in np.arange(0.9,0.05,-0.05):
    params_i = {'omega_A':0.25, 'omega_B':om, 'sigma_A':0.3, 'sigma_B':1.0}
    try:
        # Solving Phase
        functions, guess = est.Solve_Model(F, params_i, workers, firms, 'positive', 6000, 'lsoda', h_theta)
        mu_hat, theta_hat, w_hat = functions
        err = (est.Calculate_MSE((xs, ys, thetas, ws), (mu_hat, theta_hat, w_hat)))
        # Storage phase
        results_i = np.hstack((om,err))        
        results12 = np.vstack((results12,results_i))
        # Update phase
        h_theta = guess
        print 'Done with', om
    except AssertionError:
        results_i = np.hstack((om,'Failure'))
        bad_result12 = np.vstack((bad_result12,results_i))
        print 'Skipped error', om
        pass
# Out:
# Skipped error 0.9
# Skipped error 0.85
# Success! All workers and firms are matched
# Done with 0.8
# Success! All workers and firms are matched
# Done with 0.75
# Success! All workers and firms are matched
# Done with 0.7
# Success! All workers and firms are matched
# Done with 0.65
# Success! All workers and firms are matched
# Done with 0.6
# Success! All workers and firms are matched
# Done with 0.55
# Success! All workers and firms are matched
# Done with 0.5
# Success! All workers and firms are matched
# Done with 0.45
# Success! All workers and firms are matched
# Done with 0.4
# Skipped error 0.35
# Skipped error 0.3
# Skipped error 0.25
# Skipped error 0.2
# Skipped error 0.15
# Skipped error 0.1

# %% [markdown]
# ## $\omega_a$

# %%
h_theta = 100
results1 = np.zeros(2)
bad_result1 = np.zeros(2)
for om in np.arange(0.1,0.95,0.05):
    params_i = {'omega_A':om, 'omega_B':0.75, 'sigma_A':0.6, 'sigma_B':1.0}
    try:
        # Solving Phase
        functions, guess = est.Solve_Model(F, params_i, workers, firms, 'positive', 6000, 'lsoda', h_theta)
        mu_hat, theta_hat, w_hat = functions
        err = (est.Calculate_MSE((xs, ys, thetas, ws), (mu_hat, theta_hat, w_hat)))
        # Storage phase
        results_i = np.hstack((om,err))        
        results1 = np.vstack((results1,results_i))
        # Update phase
        h_theta = guess
        print 'Done with', om
    except AssertionError:
        results_i = np.hstack((om,'Failure'))
        bad_result1 = np.vstack((bad_result1,results_i))
        print 'Skipped error', om
        pass
# Out:
# Success! All workers and firms are matched
# Done with 0.1
# Success! All workers and firms are matched
# Done with 0.15
# Success! All workers and firms are matched
# Done with 0.2
# Success! All workers and firms are matched
# Done with 0.25
# Success! All workers and firms are matched
# Done with 0.3
# Success! All workers and firms are matched
# Done with 0.35
# Success! All workers and firms are matched
# Done with 0.4
# Success! All workers and firms are matched
# Done with 0.45
# Success! All workers and firms are matched
# Done with 0.5
# Success! All workers and firms are matched
# Done with 0.55
# Success! All workers and firms are matched
# Done with 0.6
# Success! All workers and firms are matched
# Done with 0.65
# Success! All workers and firms are matched
# Done with 0.7
# Success! All workers and firms are matched
# Done with 0.75
# Success! All workers and firms are matched
# Done with 0.8
# Success! All workers and firms are matched
# Done with 0.85
# Success! All workers and firms are matched
# Done with 0.9

# %%
h_theta = 100
results2 = np.zeros(2)
bad_result2 = np.zeros(2)
for om in np.arange(0.1,0.95,0.05):
    params_i = {'omega_A':om, 'omega_B':0.25, 'sigma_A':0.6, 'sigma_B':1.0}
    try:
        # Solving Phase
        functions, guess = est.Solve_Model(F, params_i, workers, firms, 'positive', 6000, 'lsoda', h_theta)
        mu_hat, theta_hat, w_hat = functions
        err = (est.Calculate_MSE((xs, ys, thetas, ws), (mu_hat, theta_hat, w_hat)))
        # Storage phase
        results_i = np.hstack((om,err))        
        results2 = np.vstack((results2,results_i))
        # Update phase
        h_theta = guess
        print 'Done with', om
    except AssertionError:
        results_i = np.hstack((om,'Failure'))
        bad_result2 = np.vstack((bad_result2,results_i))
        print 'Skipped error', om
        pass
# Out:
# Skipped error 0.1
# Skipped error 0.15
# Skipped error 0.2
# Skipped error 0.25
# Skipped error 0.3
# Success! All workers and firms are matched
# Done with 0.35
# Skipped error 0.4
# Skipped error 0.45
# Skipped error 0.5
# Skipped error 0.55
# Skipped error 0.6
# Success! All workers and firms are matched
# Done with 0.65
# Skipped error 0.7
# Skipped error 0.75
# Skipped error 0.8
# Success! All workers and firms are matched
# Done with 0.85
# Skipped error 0.9

# %%
h_theta = 100
results3 = np.zeros(2)
bad_result3 = np.zeros(2)
for om in np.arange(0.1,0.95,0.05):
    params_i = {'omega_A':om, 'omega_B':0.25, 'sigma_A':0.3, 'sigma_B':1.0}
    try:
        # Solving Phase
        functions, guess = est.Solve_Model(F, params_i, workers, firms, 'positive', 6000, 'lsoda', h_theta)
        mu_hat, theta_hat, w_hat = functions
        err = (est.Calculate_MSE((xs, ys, thetas, ws), (mu_hat, theta_hat, w_hat)))
        # Storage phase
        results_i = np.hstack((om,err))        
        results3 = np.vstack((results3,results_i))
        # Update phase
        h_theta = guess
        print 'Done with', om
    except AssertionError:
        results_i = np.hstack((om,'Failure'))
        bad_result3 = np.vstack((bad_result3,results_i))
        print 'Skipped error', om
        pass
# Out:
# Skipped error 0.1
# Skipped error 0.15
# Skipped error 0.2
# Skipped error 0.25
# Skipped error 0.3
# Skipped error 0.35
# Skipped error 0.4
# Skipped error 0.45
# Skipped error 0.5
# Skipped error 0.55
# Skipped error 0.6
# Skipped error 0.65
# Skipped error 0.7
# Skipped error 0.75
# Skipped error 0.8
# Skipped error 0.85
# Skipped error 0.9

# %%
h_theta = 100
results4 = np.zeros(2)
bad_result4 = np.zeros(2)
for om in np.arange(0.1,0.95,0.05):
    params_i = {'omega_A':om, 'omega_B':0.75, 'sigma_A':0.3, 'sigma_B':1.0}
    try:
        # Solving Phase
        functions, guess = est.Solve_Model(F, params_i, workers, firms, 'positive', 6000, 'lsoda', h_theta)
        mu_hat, theta_hat, w_hat = functions
        err = (est.Calculate_MSE((xs, ys, thetas, ws), (mu_hat, theta_hat, w_hat)))
        # Storage phase
        results_i = np.hstack((om,err))        
        results4 = np.vstack((results4,results_i))
        # Update phase
        h_theta = guess
        print 'Done with', om
    except AssertionError:
        results_i = np.hstack((om,'Failure'))
        bad_result4 = np.vstack((bad_result4,results_i))
        print 'Skipped error', om
        pass
# Out:
# Success! All workers and firms are matched
# Done with 0.1
# Success! All workers and firms are matched
# Done with 0.15
# Success! All workers and firms are matched
# Done with 0.2
# Success! All workers and firms are matched
# Done with 0.25
# Success! All workers and firms are matched
# Done with 0.3
# Success! All workers and firms are matched
# Done with 0.35
# Success! All workers and firms are matched
# Done with 0.4
# Success! All workers and firms are matched
# Done with 0.45
# Success! All workers and firms are matched
# Done with 0.5
# Success! All workers and firms are matched
# Done with 0.55
# Success! All workers and firms are matched
# Done with 0.6
# Success! All workers and firms are matched
# Done with 0.65
# Success! All workers and firms are matched
# Done with 0.7
# Success! All workers and firms are matched
# Done with 0.75
# Success! All workers and firms are matched
# Done with 0.8
# Success! All workers and firms are matched
# Done with 0.85
# Success! All workers and firms are matched
# Done with 0.9

# %% [markdown]
# ## $\sigma$

# %%
h_theta = 100
results5 = np.zeros(2)
bad_result5 = np.zeros(2)
for om in np.arange(0.9,0.05,-0.05):
    params_i = {'omega_A':0.75, 'omega_B':0.75, 'sigma_A':om, 'sigma_B':1.0}
    try:
        # Solving Phase
        functions, guess = est.Solve_Model(F, params_i, workers, firms, 'positive', 6000, 'lsoda', h_theta)
        mu_hat, theta_hat, w_hat = functions
        err = (est.Calculate_MSE((xs, ys, thetas, ws), (mu_hat, theta_hat, w_hat)))
        # Storage phase
        results_i = np.hstack((om,err))        
        results5 = np.vstack((results5,results_i))
        # Update phase
        h_theta = guess
        print 'Done with', om
    except AssertionError:
        results_i = np.hstack((om,'Failure'))
        bad_result5 = np.vstack((bad_result5,results_i))
        print 'Skipped error', om
        pass
# Out:
# Success! All workers and firms are matched
# Done with 0.9
# Success! All workers and firms are matched
# Done with 0.85
# Success! All workers and firms are matched
# Done with 0.8
# Success! All workers and firms are matched
# Done with 0.75
# Success! All workers and firms are matched
# Done with 0.7
# Success! All workers and firms are matched
# Done with 0.65
# Success! All workers and firms are matched
# Done with 0.6
# Success! All workers and firms are matched
# Done with 0.55
# Success! All workers and firms are matched
# Done with 0.5
# Success! All workers and firms are matched
# Done with 0.45
# Success! All workers and firms are matched
# Done with 0.4
# Success! All workers and firms are matched
# Done with 0.35
# Success! All workers and firms are matched
# Done with 0.3
# Success! All workers and firms are matched
# Done with 0.25
# Success! All workers and firms are matched
# Done with 0.2
# Success! All workers and firms are matched
# Done with 0.15
# Success! All workers and firms are matched
# Done with 0.1

# %%
h_theta = 100
results6 = np.zeros(2)
bad_result6 = np.zeros(2)
for om in np.arange(0.1,0.95,0.05):
    params_i = {'omega_A':0.75, 'omega_B':0.25, 'sigma_A':om, 'sigma_B':1.0}
    try:
        # Solving Phase
        functions, guess = est.Solve_Model(F, params_i, workers, firms, 'positive', 6000, 'lsoda', h_theta)
        mu_hat, theta_hat, w_hat = functions
        err = (est.Calculate_MSE((xs, ys, thetas, ws), (mu_hat, theta_hat, w_hat)))
        # Storage phase
        results_i = np.hstack((om,err))        
        results6 = np.vstack((results6,results_i))
        # Update phase
        h_theta = guess
        print 'Done with', om
    except AssertionError:
        results_i = np.hstack((om,'Failure'))
        bad_result6 = np.vstack((bad_result6,results_i))
        print 'Skipped error', om
        pass
# Out:
# Skipped error 0.1
# Skipped error 0.15
# Skipped error 0.2
# Skipped error 0.25
# Skipped error 0.3
# Success! All workers and firms are matched
# Done with 0.35
# Skipped error 0.4
# Skipped error 0.45
# Skipped error 0.5
# Skipped error 0.55
# Skipped error 0.6
# Skipped error 0.65
# Skipped error 0.7
# Skipped error 0.75
# Skipped error 0.8
# Skipped error 0.85
# Skipped error 0.9

# %%
h_theta = 100
results7 = np.zeros(2)
bad_result7 = np.zeros(2)
for om in np.arange(0.9,0.05,-0.05):
    params_i = {'omega_A':0.25, 'omega_B':0.75, 'sigma_A':om, 'sigma_B':1.0}
    try:
        # Solving Phase
        functions, guess = est.Solve_Model(F, params_i, workers, firms, 'positive', 6000, 'lsoda', h_theta)
        mu_hat, theta_hat, w_hat = functions
        err = (est.Calculate_MSE((xs, ys, thetas, ws), (mu_hat, theta_hat, w_hat)))
        # Storage phase
        results_i = np.hstack((om,err))        
        results7 = np.vstack((results7,results_i))
        # Update phase
        h_theta = guess
        print 'Done with', om
    except AssertionError:
        results_i = np.hstack((om,'Failure'))
        bad_result7 = np.vstack((bad_result7,results_i))
        print 'Skipped error', om
        pass
# Out:
# Success! All workers and firms are matched
# Done with 0.9
# Success! All workers and firms are matched
# Done with 0.85
# Success! All workers and firms are matched
# Done with 0.8
# Success! All workers and firms are matched
# Done with 0.75
# Success! All workers and firms are matched
# Done with 0.7
# Success! All workers and firms are matched
# Done with 0.65
# Success! All workers and firms are matched
# Done with 0.6
# Success! All workers and firms are matched
# Done with 0.55
# Success! All workers and firms are matched
# Done with 0.5
# Success! All workers and firms are matched
# Done with 0.45
# Success! All workers and firms are matched
# Done with 0.4
# Success! All workers and firms are matched
# Done with 0.35
# Success! All workers and firms are matched
# Done with 0.3
# Success! All workers and firms are matched
# Done with 0.25
# Success! All workers and firms are matched
# Done with 0.2
# Success! All workers and firms are matched
# Done with 0.15
# Success! All workers and firms are matched
# Done with 0.1

# %%
h_theta = 100
results8 = np.zeros(2)
bad_result8 = np.zeros(2)
for om in np.arange(0.9,0.05,-0.05):
    params_i = {'omega_A':0.25, 'omega_B':0.4, 'sigma_A':om, 'sigma_B':1.0}
    try:
        # Solving Phase
        functions, guess = est.Solve_Model(F, params_i, workers, firms, 'positive', 6000, 'lsoda', h_theta)
        mu_hat, theta_hat, w_hat = functions
        err = (est.Calculate_MSE((xs, ys, thetas, ws), (mu_hat, theta_hat, w_hat)))
        # Storage phase
        results_i = np.hstack((om,err))        
        results8 = np.vstack((results8,results_i))
        # Update phase
        h_theta = guess
        print 'Done with', om
    except AssertionError:
        results_i = np.hstack((om,'Failure'))
        bad_result8 = np.vstack((bad_result8,results_i))
        print 'Skipped error', om
        pass
# Out:
# Skipped error 0.9
# Success! All workers and firms are matched
# Done with 0.85
# Skipped error 0.8
# Success! All workers and firms are matched
# Done with 0.75
# Success! All workers and firms are matched
# Done with 0.7
# Success! All workers and firms are matched
# Done with 0.65
# Success! All workers and firms are matched
# Done with 0.6
# Success! All workers and firms are matched
# Done with 0.55
# Success! All workers and firms are matched
# Done with 0.5
# Success! All workers and firms are matched
# Done with 0.45
# Success! All workers and firms are matched
# Done with 0.4
# Success! All workers and firms are matched
# Done with 0.35
# Success! All workers and firms are matched
# Done with 0.3
# Success! All workers and firms are matched
# Done with 0.25
# Success! All workers and firms are matched
# Done with 0.2
# Success! All workers and firms are matched
# Done with 0.15
# Success! All workers and firms are matched
# Done with 0.1

# %%
best_pams = []
overlord = [100000000000, 0]
count = 1
for combo in All_results:
    if len(combo.ravel())==2:
        count+=1
        pass
    else:
        bestie = min(combo[1:,1])
        maker = combo[np.where(combo[:,1] == bestie)[0]]
        best_pams.append((count,maker))
        if bestie < overlord[0]:
            overlord[0] = bestie
            overlord[1] = (count, maker)
        count +=1

# %%
overlord[1]
# Out:
# (11, array([[   0.9       ,  337.51453811]]))

# %%
params_i = {'omega_A':0.75, 'omega_B':0.9, 'sigma_A':0.3, 'sigma_B':1.0}
functions, guess = est.Solve_Model(F, params_i, workers, firms, 'positive', 6000, 'lsoda', 100)
mu_hat, theta_hat, w_hat = functions
# Out:
# Success! All workers and firms are matched

# %%
guess
# Out:
# 2.2901520537071285

# %%
# Plotting the function vs the data (some fit better than others)
mus1 = []
xs_copy = np.sort(xs)
for i in range(len(xs_copy)):
    mus1.append(theta_hat(xs_copy[i]))
plt.plot(xs_copy, mus1, c='black')
plt.scatter(xs, thetas, c='r')
#plt.xlim(0.7,1.5)
#plt.ylim(0.85,1.2)
plt.show()

# %% [markdown]
# ## Estimation

# %%
# Starting, arbitrary parameters
ps = (0.9, 0.9, 0.3)

# Reading data from csv file
xs, ys, thetas, ws = est.import_data('data05_normed2.csv', ID=False)

# Worker skill parameters are taken from Histograms.ipynb - and correspond to log wages mean and variance
skill_p = (1.0000000000000002, 0.16382221849787501)
skill_b = [1e-2, 1.4991086434]

#skill_p = (3.8894753094349528, 0.63718247398434291)
#skill_b = [0.01, 340.6127]

# Firm skill parameters are also taken from Histograms.ipynb - and correspond to log profit mean and variance (firm level)
firm_p = (1.0000000000000002, 0.26979838777863219)
firm_b = [0.0921194652671, 1.95530939088]

#firm_p = (7.13768801209, 1.92573671813)
#firm_b = [1.93, 1151284.0]

# %%
import estimation_code_norm as est

# %%
# Starting, arbitrary parameters
ps = (0.6,  0.75,  0.37837383, 1e2)

# Reading data from csv file
pis, thetas, ws = est.import_data2('SPA05.csv', ID=False)

# Worker skill parameters are taken from Histograms.ipynb - and correspond to log wages mean and variance
skill_p = (0.0, 1.0)
skill_b = [1e-2, 5.0]

#skill_p = (3.8894753094349528, 0.63718247398434291)
#skill_b = [0.01, 340.6127]

# Firm skill parameters are also taken from Histograms.ipynb - and correspond to log profit mean and variance (firm level)
firm_p = (0.0, 1.0)
firm_b = [1e-2, 5.0]

#firm_p = (7.13768801209, 1.92573671813)
#firm_b = [1.93, 1151284.0]

# %%
res = optimize.minimize(est.StubbornObjectiveFunction2, (0.9, 0.60, 0.30,90.53818477), args=((pis, thetas, ws), skill_p, skill_b, firm_p, firm_b, 6.0), method='L-BFGS-B', jac=None, hess=None, hessp=None, bounds=((1e-3,1.0-1e-3),(1e-3,1.0-1e-3),(1e-3,None),(1e-3,None)), constraints=(), tol=None, callback=None, options=None)
# Out:
# Success! All workers and firms are matched
# 84.908234379 [  0.59113953   0.55909586   0.27660712  90.53818477]
# Success! All workers and firms are matched
# 84.9080999818 [  0.59113954   0.55909586   0.27660712  90.53818477]
# Success! All workers and firms are matched
# 84.9077395156 [  0.59113953   0.55909587   0.27660712  90.53818477]
# Success! All workers and firms are matched
# 84.9077487211 [  0.59113953   0.55909586   0.27660713  90.53818477]
# Success! All workers and firms are matched
# 84.9082336416 [  0.59113953   0.55909586   0.27660712  90.53818478]
# Wooops!  [  0.59114793   0.55910492   1.27660597  90.53970311] Approximated solution failed to satisfy required assortativity condition.
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-69-7160a80bacac> in <module>()
# ----> 1 res = optimize.minimize(est.StubbornObjectiveFunction2, (0.59113953, 0.55909586, 0.27660712,90.53818477), args=((pis, thetas, ws), skill_p, skill_b, firm_p, firm_b, 6.0), method='L-BFGS-B', jac=None, hess=None, hessp=None, bounds=((1e-3,1.0-1e-3),(1e-3,1.0-1e-3),(1e-3,None),(1e-3,None)), constraints=(), tol=None, callback=None, options=None)
#
# C:\Users\s1254888\Canopy\Environment\User\lib\site-packages\scipy\optimize\_minimize.pyc in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     425     elif meth == 'l-bfgs-b':
#     426         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
# --> 427                                 callback=callback, **options)
#     428     elif meth == 'tnc':
#     429         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#
# C:\Users\s1254888\Canopy\Environment\User\lib\site-packages\scipy\optimize\lbfgsb.pyc in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, **unknown_options)
#     313                 # minimization routine wants f and g at the current x
#     314                 # Overwrite f and g:
# --> 315                 f, g = func_and_grad(x)
#     316         elif task_str.startswith(b'NEW_X'):
#     317             # new iteration
#
# C:\Users\s1254888\Canopy\Environment\User\lib\site-packages\scipy\optimize\lbfgsb.pyc in func_and_grad(x)
#     259     if jac is None:
#     260         def func_and_grad(x):
# --> 261             f = fun(x, *args)
#     262             g = _approx_fprime_helper(x, fun, epsilon, args=args, f0=f)
#     263             return f, g
#
# C:\Users\s1254888\Canopy\Environment\User\lib\site-packages\scipy\optimize\optimize.pyc in function_wrapper(*wrapper_args)
#     280     def function_wrapper(*wrapper_args):
#     281         ncalls[0] += 1
# --> 282         return function(*(wrapper_args + args))
#     283
#     284     return ncalls, function_wrapper
#
# E:\PJ\Data\estimation_code_norm.py in StubbornObjectiveFunction2(params, data, x_pam, x_bounds, y_pam, y_bounds, guess)
#     594                 print "Wooops! ", params, e
#     595                 try:
# --> 596                         sol = Solve_Model2(F, F_params, workers, firms, 'negative', 6000.0, 'lsoda', guess)
#     597                 except ValueError, e:
#     598                         print "OK JUST LEAVE IT", params, "error:", e
#
# E:\PJ\Data\estimation_code_norm.py in Solve_Model2(Fnc, F_params, workers, firms, ass, N_knots, intg, ini, tolerance)
#     102         ''' 1.Solve the Model '''
#     103 	solver.solve(ini, tol=tolerance, number_knots=N_knots, integrator=intg,
# --> 104         	     atol=1e-12, rtol=1e-9)
#     105
#     106         ''' 2.Check it is truly solved '''
#
# E:\PJ\Data\shooting.pyc in solve(self, guess_firm_size_upper, tol, number_knots, integrator, message, **kwargs)
#     317         while self.ivp.successful():
#     318
# --> 319             self._update_solution(step_size)
#     320
#     321             if self._converged_workers(tol) and self._converged_firms(tol):
#
# E:\PJ\Data\shooting.pyc in _update_solution(self, step_size)
#     215             x, V = self.ivp.t, self.ivp.y
#     216
# --> 217         assert V[1] > 0.0, "Firm size should be non-negative!"
#     218
#     219         # update the putative equilibrium solution
#
# AssertionError: Firm size should be non-negative!

# %%
res
# Out:
#   status: 2
#  success: False
#     nfev: 1425
#      fun: 84.906906000382605
#        x: array([  0.59113953,   0.55909586,   0.27660712,  90.53818476])
#  message: 'ABNORMAL_TERMINATION_IN_LNSRCH'
#      jac: array([  1.23975579e+05,   8.81216357e+04,   8.91410494e+04,
#         -5.17139668e+01])
#      nit: 23

# %%
res = optimize.minimize(est.BulletProofObjectiveFunction, (0.55, 0.9, 0.3), args=((xs, ys, thetas, ws), skill_p, skill_b, firm_p, firm_b, 100.0), method='L-BFGS-B', jac=None, hess=None, hessp=None, bounds=((1e-3,1.0-1e-3),(1e-3,1.0-1e-3),(1e-3,None)), constraints=(), tol=None, callback=None, options=None)
# Out:
# Success! All workers and firms are matched
# Success! All workers and firms are matched
# Success! All workers and firms are matched
# Success! All workers and firms are matched
# Success! All workers and firms are matched
# Success! All workers and firms are matched
# Success! All workers and firms are matched
# Success! All workers and firms are matched
# Success! All workers and firms are matched
# Success! All workers and firms are matched

# %%
res
# Out:
#   status: 0
#  success: True
#     nfev: 15
#      fun: 649.63568352502125
#        x: array([ 0.55,  0.9 ,  0.3 ])
#  message: 'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      jac: array([ -3656.270178  ,  12637.01185508,   1855.53847132])
#      nit: 1

# %% [markdown]
# ### Appendix

# %%
# Pottentially useful bit of code
rxs = solver.solution.index.values
rmus = solver.solution['$\\mu(x)$'].values
rthetas = solver.solution['$\\theta(x)$'].values
rws = solver.solution['$w(x)$'].values

# %%
plt.plot(results_i[:-5])
plt.xlim(0,35)
plt.scatter(results_i.index(min(results_i)), min(results_i))
plt.show()
print "Best result:",min(results_i),"; Omega:",0.4
# Out:
# Best result: 9608553.88584 ; Omega: 0.4
