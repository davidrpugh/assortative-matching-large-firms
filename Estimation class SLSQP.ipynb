# %%
# %matplotlib inline

# %%
# %load_ext autoreload

# %%
autoreload 2

# %%
import matplotlib.pyplot as plt
from scipy import stats, optimize
import numpy as np
import sympy as sym

import inputs
import models
import shooting

from __future__ import division
#from sympy import init_printing

# %%
from estimation_class2 import *

# %% [markdown]
# # Estimation for Spain
#
# ## Production function:
#
# ### $$ A_s * Big A * (\omega_A  * x^{\frac{\sigma-1}{\sigma}}+(1-\omega_A)  * y^{\frac{\sigma-1}{\sigma}} )^{\frac{\sigma}{\sigma-1}} * l^{\omega_B} * r^{(1-\omega_B)} $$
#
# **Parameter restrictions**:
# - $\omega_B > \omega_A $: This makes sure that bigger firms hire better workers.
# - $\sigma < 1 $: This ensures PAM.
#
# Finally, $A_s$ is a scaling factor for $Big A$. As  $Big A$ can get quite big, for the minimizing routine it is best to first scale it up by A_s and then letting the minimization work with similar quantities as the parameters.
#
# ###This imports the code, stores the data and dispalys it:

# %%
knots= np.logspace(np.log(0.005), np.log(20.0), 1000,endpoint=True, base=np.e)
est1 = HTWF_Estimation((0.0,1.0), (0.005, 20.0), (0.0,1.0), (0.005, 20.0), 142.85, 100000.0, knots)
est1.InitializeFunction()
est1.import_data('SPA05.csv', ID=False, weights=False, logs=False, yearly_w=True)
est1.Plot_data()

# %%
besties = (0.63023927,  0.8037265,   0.67336212,  1.33407531)
# try it out   
F_params = {'omega_A':besties[0], 'omega_B':besties[1], 'sigma_A':besties[2], 'Big_A':besties[3]}
functions_f_model = est1.Solve_Model(F_params, None, 'vode', 1e3, 1e-3)
est1.Plot_solution()
# Out:
# Success! All workers and firms are matched

# %% [markdown]
# So we have:
#
# - A relationship between (annual) log wages and log firm size.
# - A relationship between (annual) log profits and log firm size.
# - A distribution of log firm size.
#
# The model spits out:
# - A function that relates $wage \to \theta$ (not in logs, we take them when calculating the error)
# - A function that relates $\pi \to \theta$ (not in logs, we take them when calculating the error)
# - The gridgpoints of $x$ with their corresponding $\theta$s. From there we build the distribution via:$ \frac{pdf(x_i)}{\theta_i} = pdf(\theta_i)$ (plus take logs and normalize)
#
#
# ### The objective function:
#
# ##$$ min_{{\omega_A,\omega_B,\sigma,Big_A}} \sum_i{(\theta_i - \hat\theta_i(wage_i))^2 + (\theta_i - \hat\theta_i(\pi_i))^2 + (cdf_{\theta}(\theta_i) - \hat{cdf}_{\theta}(\theta_i))^2}$$
#
# There is a penalty of **100.0** for not having some points in the solution (so data points smaller than the smallest size from the model or data points bigger than the biggest size from the model). We can change this in the future.
#
# ### The following puts everything into the minimization routine
#
# About the minimization routine, this is the best one we've found so far in python. It takes a while because you can't simply take derivatives of the objective function. Next week we'll look up alternatives / ways to make the solver faster and more precise.

# %%
ps = (0.63023927,  0.8037265,   0.67336212,  1.33407531)
# constraints (w_b>w_a)
cons = ({'type': 'ineq',
         'fun' : lambda ps: np.array([ps[1]- ps[0]]),
         'jac' : lambda ps: np.array([-1.0, 1.0, 0.0, 0.0])})
res = optimize.minimize(est1.StubbornObjectiveFunction, ps, args=(None, 1e-3, 1e4),
               bounds=((1e-2,1.0-1e-2),(1e-2,1.0-1e-2),(1e-2,1.0-1e-2),(0.5,2.0)),
               constraints=cons, method='SLSQP', options={'disp': True})
# Out:
# Success! All workers and firms are matched
# 1119.59478089 [ 0.63023927  0.8037265   0.67336212  1.33407531]
# Success! All workers and firms are matched
# 1119.59478089 [ 0.63023927  0.8037265   0.67336212  1.33407531]
# Success! All workers and firms are matched
# 1119.59476081 [ 0.63023928  0.8037265   0.67336212  1.33407531]
# Success! All workers and firms are matched
# 1119.59479811 [ 0.63023927  0.80372651  0.67336212  1.33407531]
# Success! All workers and firms are matched
# 1119.59478767 [ 0.63023927  0.8037265   0.67336213  1.33407531]
# Success! All workers and firms are matched
# 1119.59478059 [ 0.63023927  0.8037265   0.67336212  1.33407532]
# K. [ 0.9899998   0.99000017  0.01000007  2.        ] error: Fail to solve!
# Success! All workers and firms are matched
# 1569.13993859 [ 0.66621532  0.82235387  0.60702591  1.40066778]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-4d0baf27c9c0> in <module>()
#       6 res = optimize.minimize(est1.StubbornObjectiveFunction, ps, args=(None, 1e-3, 1e4),
#       7                bounds=((1e-2,1.0-1e-2),(1e-2,1.0-1e-2),(1e-2,1.0-1e-2),(0.5,2.0)),
# ----> 8                constraints=cons, method='SLSQP', options={'disp': True})
#
# /Users/juliafaltermeier/anaconda/lib/python2.7/site-packages/scipy/optimize/_minimize.pyc in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     433     elif meth == 'slsqp':
#     434         return _minimize_slsqp(fun, x0, args, jac, bounds,
# --> 435                                constraints, callback=callback, **options)
#     436     elif meth == 'dogleg':
#     437         return _minimize_dogleg(fun, x0, args, jac, hess,
#
# /Users/juliafaltermeier/anaconda/lib/python2.7/site-packages/scipy/optimize/slsqp.pyc in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, callback, **unknown_options)
#     358
#     359             # Compute objective function
# --> 360             fx = func(x)
#     361             # Compute the constraints
#     362             if cons['eq']:
#
# /Users/juliafaltermeier/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in function_wrapper(*wrapper_args)
#     279     def function_wrapper(*wrapper_args):
#     280         ncalls[0] += 1
# --> 281         return function(*(wrapper_args + args))
#     282
#     283     return ncalls, function_wrapper
#
# /Users/juliafaltermeier/Documents/Eeckhout/assortative-matching-large-firms/estimation_class2.py in StubbornObjectiveFunction(self, params, N_points, tol_i, guess)
#     450                 # 3. Solve the model
#     451                 try:
# --> 452                         sol = self.Solve_Model(F_params, N_points, 'lsoda', guess, tol_i)
#     453                 except AssertionError ,e:
#     454                         if e=='Failure! Need to increase initial guess for upper bound on firm size!':
#
# /Users/juliafaltermeier/Documents/Eeckhout/assortative-matching-large-firms/estimation_class2.py in Solve_Model(self, F_params, N_knots, intg, ini, tolerance)
#     290                 solver = shooting.ShootingSolver(model=modelA)
#     291                 ''' 1.Solve the Model '''
# --> 292                 solver.solve(ini, tol=tolerance, number_knots=N_knots, knots=self.knots, integrator=intg)
#     293
#     294                 ''' 2.Check it is truly solved '''
#
# /Users/juliafaltermeier/Documents/Eeckhout/assortative-matching-large-firms/shooting.py in solve(self, guess_firm_size_upper, tol, number_knots, knots, integrator, message, **kwargs)
#     341         while self.ivp.successful():
#     342
# --> 343             self._update_solution(step_sizes[idx])
#     344
#     345             if self._converged_workers(tol) and self._converged_firms(tol):
#
# /Users/juliafaltermeier/Documents/Eeckhout/assortative-matching-large-firms/shooting.py in _update_solution(self, step_size)
#     211         """Update the solution array after an integration step."""
#     212         if self.model.assortativity == 'positive':
# --> 213             self.ivp.integrate(self.ivp.t - step_size)
#     214             x, V = self.ivp.t, self.ivp.y
#     215         else:
#
# /Users/juliafaltermeier/anaconda/lib/python2.7/site-packages/scipy/integrate/_ode.pyc in integrate(self, t, step, relax)
#     386             self._y, self.t = mth(self.f, self.jac or (lambda: None),
#     387                                 self._y, self.t, t,
# --> 388                                 self.f_params, self.jac_params)
#     389         except SystemError:
#     390             # f2py issue with tuple returns, see ticket 1187.
#
# /Users/juliafaltermeier/anaconda/lib/python2.7/site-packages/scipy/integrate/_ode.pyc in run(self, f, jac, y0, t0, t1, f_params, jac_params)
#    1121         args = [f, y0, t0, t1] + self.call_args[:-1] + \
#    1122                [jac, self.call_args[-1], f_params, 0, jac_params]
# -> 1123         y1, t, istate = self.runner(*args)
#    1124         if istate < 0:
#    1125             warnings.warn('lsoda: ' +
#
# /Users/juliafaltermeier/Documents/Eeckhout/assortative-matching-large-firms/shooting.py in evaluate_rhs(self, x, V)
#     264
#     265         """
# --> 266         rhs = self._numeric_system(x, V, *self.model.params.values()).ravel()
#     267         return rhs
#     268
#
# /Users/juliafaltermeier/Documents/Eeckhout/assortative-matching-large-firms/models.py in params(self)
#     192         """
#     193         model_params = dict(self.F_params.items() +
# --> 194                             self.workers.params.items() +
#     195                             self.firms.params.items())
#     196         return self._order_params(model_params)
#
# KeyboardInterrupt:

# %%
est1.write_solution_path()

# %% [markdown]
# Although this particular run didn't succeed, I have one case of success. The lowest point so far is is given by:
#
# $$ \omega_A :0.59031046 , \omega_B :0.78435585, \sigma_A :0.74916621, Big_A :1.25752894 $$
#
# Below is represented the fit to the data.

# %%
besties = (0.63023927,  0.8037265,   0.67336212,  1.33407531)
# try it out   
F_params = {'omega_A':besties[0], 'omega_B':besties[1], 'sigma_A':besties[0], 'Big_A':besties[0]}
functions_f_model = est1.Solve_Model(F_params, None, knots,'vode', 1e3, 1e-3)
# Out:
# Success! All workers and firms are matched

# %%
est1.Plot_solution()

# %% [markdown]
# Note: remember that everythging is in logs, so althought the functions from the model seem linear, they are not.
#
# Not a great job for profits and wages (wages from the model tend to be way smaller than profits, and in may data the profit is the "retribution to the entrepreneur" - which is a salary to him at the end of the day). The distribution of firm sizes is pretty good. The median seems to be a hit.
