# %%
# %load_ext autoreload

# %%
autoreload 2

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
from scipy import stats, optimize
import numpy as np
import sympy as sym

import inputs
import models
import shooting
import operator
import csv

from __future__ import division
#from sympy import init_printing

# %%
from estimation_class import *

# %% [markdown]
# #Notebook to test minimiser using simulated 'dummy' data (now for German parameters)

# %% [markdown]
# ##Solve the model for some parameters

# %%
est1 = HTWF_Estimation((0.0,1.0), (0.005, 200.0), (0.0,1.0), (0.005, 200.0), 14.0,
                       100000.0)

# %%
est1.InitializeFunction()

# %% [markdown]
# Note on the data:
# - all variables are given in logs
# - wages are annualised by multiplying: (daily wage)*360
# - German data has weights to make sample representative of population which are used in the estimation

# %% [markdown]
# see Cristina's file for more detailed explanation on the solution method

# %%
#Choose the tolerance
toll = 1e-4

# Here input your grid
knots= np.logspace(np.log(0.005), np.log(200.0), 1000,
                   endpoint=True, base=np.e)

#Choose parameters for dummy data
F_params = {'omega_A':0.0307315, 'omega_B':0.24014643, 'sigma_A': 0.83177002 , 'Big_A': 5.06956549}
functions = est1.Solve_Model(F_params, None,knots, 'lsoda', 4500.0, toll)
w_theta, pi_theta, thetas, xs_fm = functions
# Out:
# Success! All workers and firms are matched

# %%
#Plot table with points form estimation - note that we need more points with a low x to get 
#more accurate results - we are working on a log-scale for the grid
#est1.current_sol
# Out:
#               $\mu(x)$  $\theta(x)$        $w(x)$      $\pi(x)$
# x
# 0.005000      0.005000     0.017912  12935.090951  7.330992e+02
# 0.005053      0.009432     0.040119  12954.430276  1.644473e+03
# 0.005107      0.010615     0.046543  12974.555159  1.910754e+03
# 0.005162      0.011415     0.050960  12995.028497  2.095380e+03
# 0.005217      0.012045     0.054467  13015.739934  2.243139e+03
# 0.005272      0.012577     0.057445  13036.635755  2.369562e+03
# 0.005329      0.013046     0.060074  13057.683849  2.482031e+03
# 0.005385      0.013469     0.062457  13078.862651  2.584678e+03
# 0.005443      0.013860     0.064657  13100.156584  2.680070e+03
# 0.005501      0.014225     0.066716  13121.554232  2.769919e+03
# 0.005560      0.014571     0.068663  13143.047021  2.855428e+03
# 0.005619      0.014900     0.070520  13164.627328  2.937477e+03
# 0.005679      0.015216     0.072304  13186.289842  3.016734e+03
# 0.005739      0.015522     0.074027  13208.029466  3.093716e+03
# 0.005800      0.015819     0.075699  13229.841922  3.168834e+03
# 0.005862      0.016108     0.077329  13251.724490  3.242422e+03
# 0.005925      0.016391     0.078924  13273.673580  3.314754e+03
# 0.005988      0.016669     0.080488  13295.686649  3.386057e+03
# 0.006052      0.016942     0.082027  13317.761938  3.456527e+03
# 0.006116      0.017212     0.083544  13339.896995  3.526328e+03
# 0.006182      0.017478     0.085044  13362.090189  3.595603e+03
# 0.006248      0.017742     0.086529  13384.340002  3.664476e+03
# 0.006314      0.018004     0.088002  13406.645478  3.733061e+03
# 0.006382      0.018264     0.089465  13429.004646  3.801449e+03
# 0.006450      0.018522     0.090920  13451.416843  3.869731e+03
# 0.006518      0.018780     0.092369  13473.880864  3.937984e+03
# 0.006588      0.019036     0.093814  13496.395846  4.006278e+03
# 0.006658      0.019293     0.095257  13518.961427  4.074680e+03
# 0.006729      0.019549     0.096698  13541.576086  4.143245e+03
# 0.006801      0.019804     0.098139  13564.239686  4.212031e+03
# ...                ...          ...           ...           ...
# 147.040396  199.106893  2373.059717  65407.038652  4.911192e+08
# 148.608390  199.164671  2370.522875  65501.226251  4.913007e+08
# 150.193105  199.219639  2367.952891  65595.359605  4.914733e+08
# 151.794719  199.271934  2365.351932  65689.438241  4.916376e+08
# 153.413412  199.321642  2362.721506  65783.460742  4.917938e+08
# 155.049366  199.368863  2360.063249  65877.426082  4.919422e+08
# 156.702766  199.413750  2357.379529  65971.335050  4.920832e+08
# 158.373797  199.456419  2354.672179  66065.187278  4.922173e+08
# 160.062647  199.496946  2351.942517  66158.981395  4.923447e+08
# 161.769507  199.535424  2349.192002  66252.716650  4.924657e+08
# 163.494568  199.571995  2346.422782  66346.394771  4.925807e+08
# 165.238025  199.606740  2343.636167  66440.014733  4.926899e+08
# 167.000074  199.639721  2340.833204  66533.574800  4.927936e+08
# 168.780912  199.671005  2338.015006  66627.073723  4.928920e+08
# 170.580741  199.700695  2335.183120  66720.512543  4.929854e+08
# 172.399762  199.728893  2332.339034  66813.892163  4.930741e+08
# 174.238181  199.755647  2329.483608  66907.210674  4.931583e+08
# 176.096205  199.781012  2326.617749  67000.466671  4.932381e+08
# 177.974041  199.805054  2323.742561  67093.657547  4.933138e+08
# 179.871903  199.827845  2320.859300  67186.780134  4.933855e+08
# 181.790003  199.849449  2317.968745  67279.838264  4.934536e+08
# 183.728556  199.869934  2315.071692  67372.837063  4.935181e+08
# 185.687782  199.889395  2312.169075  67465.786562  4.935793e+08
# 187.667901  199.907942  2309.261941  67558.700457  4.936376e+08
# 189.669134  199.925368  2306.350465  67651.506436  4.936925e+08
# 191.691709  199.941952  2303.435824  67744.270449  4.937447e+08
# 193.735851  199.957676  2300.518606  67836.972864  4.937942e+08
# 195.801792  199.972542  2297.599405  67929.601566  4.938410e+08
# 197.889763  199.986653  2294.678861  68022.175037  4.938854e+08
# 200.000000  200.000000  2291.757330  68114.682969  4.939274e+08
#
# [1000 rows x 4 columns]

# %%
#Get data from the solution
thetas = est1.current_sol['$\\theta(x)$'].values
ws = est1.current_sol['$w(x)$'].values
pis_fm = est1.current_sol['$\\pi(x)$'].values
xs_fm = est1.current_sol.index.values
ys_fm = est1.current_sol['$\\mu(x)$']

#now write these to csv file!!
with open('dummysol.csv', 'wb') as csvfile:
    mywriter = csv.writer(csvfile, delimiter=',',quotechar='|', quoting=csv.QUOTE_MINIMAL)
    for x in range(0,len(ws)):
        mywriter.writerow([thetas[x] ,ws[x] ,pis_fm[x]])
        
#nice job, next run the solver with this data!!

# %%
est1.import_data('dummysol.csv', ID=False, weights=False, logs=False, yearly_w=False, change_weight=False)

# %% [markdown]
# ##Solution for German Data:
# This is the best solution for the German data so far, although the minimiser still hasn't finished.

# %%
est1.Plot_solution()
#Should give points exactly on the line, now firm size distribution slightly weird, 
#but maybe this is because before the data was already sorted?

# %%
#Now run the minimisation routine and see what happens...
ps = (0.04,0.4,0.8,5.0)


res = optimize.minimize(est1.StubbornObjectiveFunction, 
                        ps,args=(None,knots, 1e-4, 14500.0), 
                        method='L-BFGS-B', jac=None, hess=None, hessp=None, 
                        bounds=((1e-2,1.0-1e-2),(1e-2,1.0-1e-2),(1e-2,1.0-1e-2),(1e-2,None)), options={'eps':1e-2})
# Out:
# Success! All workers and firms are matched
# 91105.4350666 [ 0.04  0.4   0.8   5.  ]
# Success! All workers and firms are matched
# 91105.4350666

# %% [markdown]
# #Comments:
# - firm size distribution from the data looks different which it shouldn't, need to check how we calculate that!
# - now we need to test this for both minimisers, potentially using different starting parameters
